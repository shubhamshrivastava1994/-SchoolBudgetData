# %% [markdown]
# # Labeling school budget data
#
# Goal: Perform NLP on school budget data to predict accurate labels for the expenditure category using multiclass classification models from scikit learn.
#
# We will build a human-in-the-loop system by assigning a probability of labels to each line item.
#
#
#
# Data from [DrivenData](https://www.drivendata.org/competitions/46/box-plots-for-education-reboot/data/)
#
# Ref: Datacamp

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import FeatureUnion
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Imputer
from sklearn.ensemble import RandomForestClassifier

# %%
df_train = pd.read_csv('TrainingData.csv', index_col=0)

# %%
df_train.head()
# Out:
#                        Function          Use          Sharing Reporting  \
# 134338     Teacher Compensation  Instruction  School Reported    School
# 206341                 NO_LABEL     NO_LABEL         NO_LABEL  NO_LABEL
# 326408     Teacher Compensation  Instruction  School Reported    School
# 364634  Substitute Compensation  Instruction  School Reported    School
# 47683   Substitute Compensation  Instruction  School Reported    School
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# 134338     NO_LABEL       Teacher                  NO_LABEL  NO_LABEL
# 206341     NO_LABEL      NO_LABEL                  NO_LABEL  NO_LABEL
# 326408  Unspecified       Teacher  Base Salary/Compensation  Non PreK
# 364634  Unspecified    Substitute                  Benefits  NO_LABEL
# 47683   Unspecified       Teacher   Substitute Compensation  NO_LABEL
#
#          Operating_Status            Object_Description  \
# 134338  PreK-12 Operating                           NaN
# 206341      Non-Operating           CONTRACTOR SERVICES
# 326408  PreK-12 Operating  Personal Services - Teachers
# 364634  PreK-12 Operating             EMPLOYEE BENEFITS
# 47683   PreK-12 Operating  TEACHER COVERAGE FOR TEACHER
#
#                     ...               Sub_Object_Description  \
# 134338              ...                                  NaN
# 206341              ...                                  NaN
# 326408              ...                                  NaN
# 364634              ...                                  NaN
# 47683               ...                                  NaN
#
#        Location_Description  FTE     Function_Description  \
# 134338                  NaN  1.0                      NaN
# 206341                  NaN  NaN                 RGN  GOB
# 326408                  NaN  1.0                      NaN
# 364634                  NaN  NaN  UNALLOC BUDGETS/SCHOOLS
# 47683                   NaN  NaN              NON-PROJECT
#
#        Facility_or_Department              Position_Extra      Total  \
# 134338                    NaN               KINDERGARTEN   50471.810
# 206341                    NaN                UNDESIGNATED   3477.860
# 326408                    NaN                     TEACHER  62237.130
# 364634                    NaN  PROFESSIONAL-INSTRUCTIONAL     22.300
# 47683                     NaN  PROFESSIONAL-INSTRUCTIONAL     54.166
#
#                    Program_Description        Fund_Description  \
# 134338                    KINDERGARTEN            General Fund
# 206341   BUILDING IMPROVEMENT SERVICES                     NaN
# 326408           Instruction - Regular  General Purpose School
# 364634  GENERAL MIDDLE/JUNIOR HIGH SCH                     NaN
# 47683    GENERAL HIGH SCHOOL EDUCATION                     NaN
#
#                                Text_1
# 134338                            NaN
# 206341  BUILDING IMPROVEMENT SERVICES
# 326408                            NaN
# 364634            REGULAR INSTRUCTION
# 47683             REGULAR INSTRUCTION
#
# [5 rows x 25 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400277 entries, 134338 to 415831
# Data columns (total 25 columns):
# Function                  400277 non-null object
# Use                       400277 non-null object
# Sharing                   400277 non-null object
# Reporting                 400277 non-null object
# Student_Type              400277 non-null object
# Position_Type             400277 non-null object
# Object_Type               400277 non-null object
# Pre_K                     400277 non-null object
# Operating_Status          400277 non-null object
# Object_Description        375493 non-null object
# Text_2                    88217 non-null object
# SubFund_Description       306855 non-null object
# Job_Title_Description     292743 non-null object
# Text_3                    179964 non-null object
# Text_4                    53746 non-null object
# Sub_Object_Description    91603 non-null object
# Location_Description      162054 non-null object
# FTE                       126071 non-null float64
# Function_Description      342195 non-null object
# Facility_or_Department    53886 non-null object
# Position_Extra            264764 non-null object
# Total                     395722 non-null float64
# Program_Description       304660 non-null object
# Fund_Description          202877 non-null object
# Text_1                    292285 non-null object
# dtypes: float64(2), object(23)
# memory usage: 79.4+ MB

# %%
df_train.tail()
# Out:
#                             Function          Use                    Sharing  \
# 109283      Professional Development         ISPD            Shared Services
# 102430       Substitute Compensation  Instruction            School Reported
# 413949  Parent & Community Relations     NO_LABEL            School Reported
# 433672               Library & Media  Instruction  School on Central Budgets
# 415831       Substitute Compensation  Instruction            School Reported
#
#          Reporting Student_Type        Position_Type  \
# 109283  Non-School  Unspecified  Instructional Coach
# 102430      School  Unspecified           Substitute
# 413949      School     NO_LABEL                Other
# 433672  Non-School  Unspecified            Librarian
# 415831      School      Poverty           Substitute
#
#                        Object_Type     Pre_K   Operating_Status  \
# 109283  Other Compensation/Stipend  NO_LABEL  PreK-12 Operating
# 102430    Base Salary/Compensation  NO_LABEL  PreK-12 Operating
# 413949                    NO_LABEL  NO_LABEL  PreK-12 Operating
# 433672                    Benefits  NO_LABEL  PreK-12 Operating
# 415831     Substitute Compensation  Non PreK  PreK-12 Operating
#
#                                      Object_Description  \
# 109283                   WORKSHOP PARTICIPANT
# 102430                   SALARIES OF PART TIME EMPLOYEE
# 413949                                              NaN
# 433672                                EMPLOYEE BENEFITS
# 415831  Salaries And Wages For Substitute Professionals
#
#                      ...                \
# 109283               ...
# 102430               ...
# 413949               ...
# 433672               ...
# 415831               ...
#
#                             Sub_Object_Description  \
# 109283                                         NaN
# 102430                                         NaN
# 413949                                         NaN
# 433672                                         NaN
# 415831  Inservice Substitute Teachers Grant Funded
#
#                   Location_Description      FTE  \
# 109283  STAFF DEV AND INSTR MEDIA           NaN
# 102430                             NaN  0.00431
# 413949                             NaN  1.00000
# 433672            ED RESOURCE SERVICES      NaN
# 415831                         School       NaN
#
#                   Function_Description      Facility_or_Department  \
# 109283  INST STAFF TRAINING SVCS                               NaN
# 102430                      TITLE II,D                         NaN
# 413949                             NaN                         NaN
# 433672                     NON-PROJECT                         NaN
# 415831                     Instruction  Instruction And Curriculum
#
#                        Position_Extra        Total  \
# 109283                            NaN    48.620000
# 102430     PROFESSIONAL-INSTRUCTIONAL   128.824985
# 413949                 PARENT/TITLE I  4902.290000
# 433672  OFFICE/ADMINISTRATIVE SUPPORT  4020.290000
# 415831           CERTIFIED SUBSTITUTE    46.530000
#
#                  Program_Description  \
# 109283                           NaN
# 102430  INSTRUCTIONAL STAFF TRAINING
# 413949                          Misc
# 433672        MEDIA SUPPORT SERVICES
# 415831         Accelerated Education
#
#                                 Fund_Description  \
# 109283            GENERAL FUND
# 102430                                       NaN
# 413949                        Schoolwide Schools
# 433672                                       NaN
# 415831  "Title  Part A Improving Basic Programs"
#
#                                 Text_1
# 109283  STAFF DEV AND INSTR MEDIA
# 102430             INSTRUCTIONAL STAFF
# 413949                             NaN
# 433672             INSTRUCTIONAL STAFF
# 415831                  MISCELLANEOUS
#
# [5 rows x 25 columns]

# %%
df_train.columns
# Out:
# Index(['Function', 'Use', 'Sharing', 'Reporting', 'Student_Type',
#        'Position_Type', 'Object_Type', 'Pre_K', 'Operating_Status',
#        'Object_Description', 'Text_2', 'SubFund_Description',
#        'Job_Title_Description', 'Text_3', 'Text_4', 'Sub_Object_Description',
#        'Location_Description', 'FTE', 'Function_Description',
#        'Facility_or_Department', 'Position_Extra', 'Total',
#        'Program_Description', 'Fund_Description', 'Text_1'],
#       dtype='object')

# %%
df_train.describe()
# Out:
#                  FTE         Total
# count  126071.000000  3.957220e+05
# mean        0.426794  1.310586e+04
# std         0.573576  3.682254e+05
# min        -0.087551 -8.746631e+07
# 25%         0.000792  7.379770e+01
# 50%         0.130927  4.612300e+02
# 75%         1.000000  3.652662e+03
# max        46.800000  1.297000e+08

# %% [markdown]
# FTE: Stands for "full-time equivalent". If the budget item is associated to an employee, this number tells us the percentage of full-time that the employee works. A value of 1 means the associated employee works for the school full-time. A value close to 0 means the item is associated to a part-time or contracted employee.
#
# Total: Stands for the total cost of the expenditure. This number tells us how much the budget item cost.
#
# The variance in expenditure is high. Makes sense---some purchases are cheap, some are expensive.

# %%
df_train['FTE'].dropna().plot(kind = 'hist', xlim = [0, 1], bins = 500);
plt.xlabel('% of full-time');

# %% [markdown]
# Bi-modal distribution!

# %% [markdown]
# Making variables categorical.
#
# First let's look at object variables.

# %%
df_train.dtypes
# Out:
# Function                   object
# Use                        object
# Sharing                    object
# Reporting                  object
# Student_Type               object
# Position_Type              object
# Object_Type                object
# Pre_K                      object
# Operating_Status           object
# Object_Description         object
# Text_2                     object
# SubFund_Description        object
# Job_Title_Description      object
# Text_3                     object
# Text_4                     object
# Sub_Object_Description     object
# Location_Description       object
# FTE                       float64
# Function_Description       object
# Facility_or_Department     object
# Position_Extra             object
# Total                     float64
# Program_Description        object
# Fund_Description           object
# Text_1                     object
# dtype: object

# %%
df_train.dtypes.value_counts()
# Out:
# object     23
# float64     2
# dtype: int64

# %% [markdown]
# The object types are slow and don't work well with ML algorithms.
#
# For each of these rows, ERS attaches one label from each of 9 different categories as explained [here.](https://www.drivendata.org/competitions/46/box-plots-for-education-reboot/page/86/#labels_list)
#
# Next we convert these labels into categories type.

# %%
labels = ['Function',
 'Use',
 'Sharing',
 'Reporting',
 'Student_Type',
 'Position_Type',
 'Object_Type',
 'Pre_K',
 'Operating_Status']

# %%
df_train[labels].head()
# Out:
#                        Function          Use          Sharing Reporting  \
# 134338     Teacher Compensation  Instruction  School Reported    School
# 206341                 NO_LABEL     NO_LABEL         NO_LABEL  NO_LABEL
# 326408     Teacher Compensation  Instruction  School Reported    School
# 364634  Substitute Compensation  Instruction  School Reported    School
# 47683   Substitute Compensation  Instruction  School Reported    School
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# 134338     NO_LABEL       Teacher                  NO_LABEL  NO_LABEL
# 206341     NO_LABEL      NO_LABEL                  NO_LABEL  NO_LABEL
# 326408  Unspecified       Teacher  Base Salary/Compensation  Non PreK
# 364634  Unspecified    Substitute                  Benefits  NO_LABEL
# 47683   Unspecified       Teacher   Substitute Compensation  NO_LABEL
#
#          Operating_Status
# 134338  PreK-12 Operating
# 206341      Non-Operating
# 326408  PreK-12 Operating
# 364634  PreK-12 Operating
# 47683   PreK-12 Operating

# %%
df_train[labels].shape
# Out:
# (400277, 9)

# %%
set(df_train.columns) - set(labels)
# Out:
# {'FTE',
#  'Facility_or_Department',
#  'Function_Description',
#  'Fund_Description',
#  'Job_Title_Description',
#  'Location_Description',
#  'Object_Description',
#  'Position_Extra',
#  'Program_Description',
#  'SubFund_Description',
#  'Sub_Object_Description',
#  'Text_1',
#  'Text_2',
#  'Text_3',
#  'Text_4',
#  'Total'}

# %%
categorize_label = lambda lab: lab.astype('category')

# %%
df_train[labels] = df_train[labels].apply(categorize_label, axis = 'rows')

# %%
df_train[labels].head()
# Out:
#                        Function          Use          Sharing Reporting  \
# 134338     Teacher Compensation  Instruction  School Reported    School
# 206341                 NO_LABEL     NO_LABEL         NO_LABEL  NO_LABEL
# 326408     Teacher Compensation  Instruction  School Reported    School
# 364634  Substitute Compensation  Instruction  School Reported    School
# 47683   Substitute Compensation  Instruction  School Reported    School
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# 134338     NO_LABEL       Teacher                  NO_LABEL  NO_LABEL
# 206341     NO_LABEL      NO_LABEL                  NO_LABEL  NO_LABEL
# 326408  Unspecified       Teacher  Base Salary/Compensation  Non PreK
# 364634  Unspecified    Substitute                  Benefits  NO_LABEL
# 47683   Unspecified       Teacher   Substitute Compensation  NO_LABEL
#
#          Operating_Status
# 134338  PreK-12 Operating
# 206341      Non-Operating
# 326408  PreK-12 Operating
# 364634  PreK-12 Operating
# 47683   PreK-12 Operating

# %%
df_train[labels].dtypes
# Out:
# Function            category
# Use                 category
# Sharing             category
# Reporting           category
# Student_Type        category
# Position_Type       category
# Object_Type         category
# Pre_K               category
# Operating_Status    category
# dtype: object

# %%
df_train[labels].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400277 entries, 134338 to 415831
# Data columns (total 9 columns):
# Function            400277 non-null category
# Use                 400277 non-null category
# Sharing             400277 non-null category
# Reporting           400277 non-null category
# Student_Type        400277 non-null category
# Position_Type       400277 non-null category
# Object_Type         400277 non-null category
# Pre_K               400277 non-null category
# Operating_Status    400277 non-null category
# dtypes: category(9)
# memory usage: 6.5 MB

# %% [markdown]
# Counting unique labels

# %%
df_train[labels].nunique()
# Out:
# Function            37
# Use                  8
# Sharing              5
# Reporting            3
# Student_Type         9
# Position_Type       25
# Object_Type         11
# Pre_K                3
# Operating_Status     3
# dtype: int64

# %%
type(df_train[labels].nunique())
# Out:
# pandas.core.series.Series

# %%
df_train[labels].nunique().plot(kind = 'bar');
plt.ylabel('number of unique values');

# %% [markdown]
# **Model building**
#
# As a first pass build a simple model using just the numeric columns.

# %%
numeric_data = df_train.select_dtypes(include = [float]).fillna(-1000)
# filling NaNs with a large negative number

# %%
numeric_columns = list(df_train.select_dtypes(include = [float]).columns.values)

# %%
numeric_columns
# Out:
# ['FTE', 'Total']

# %%
numeric_data.head()
# Out:
#            FTE      Total
# 134338     1.0  50471.810
# 206341 -1000.0   3477.860
# 326408     1.0  62237.130
# 364634 -1000.0     22.300
# 47683  -1000.0     54.166

# %%
NUMERIC_COLUMNS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-f86d8591e6cf> in <module>()
# ----> 1 NUMERIC_COLUMNS
#
# NameError: name 'NUMERIC_COLUMNS' is not defined

# %%
df_train[numeric_columns].head()
# Out:
#         FTE      Total
# 134338  1.0  50471.810
# 206341  NaN   3477.860
# 326408  1.0  62237.130
# 364634  NaN     22.300
# 47683   NaN     54.166

# %%
df_label_dummies = pd.get_dummies(df_train[labels])

# %%
df_label_dummies.head()
# Out:
#         Function_Aides Compensation  Function_Career & Academic Counseling  \
# 134338                            0                                      0
# 206341                            0                                      0
# 326408                            0                                      0
# 364634                            0                                      0
# 47683                             0                                      0
#
#         Function_Communications  Function_Curriculum Development  \
# 134338                        0                                0
# 206341                        0                                0
# 326408                        0                                0
# 364634                        0                                0
# 47683                         0                                0
#
#         Function_Data Processing & Information Services  \
# 134338                                                0
# 206341                                                0
# 326408                                                0
# 364634                                                0
# 47683                                                 0
#
#         Function_Development & Fundraising  Function_Enrichment  \
# 134338                                   0                    0
# 206341                                   0                    0
# 326408                                   0                    0
# 364634                                   0                    0
# 47683                                    0                    0
#
#         Function_Extended Time & Tutoring  Function_Facilities & Maintenance  \
# 134338                                  0                                  0
# 206341                                  0                                  0
# 326408                                  0                                  0
# 364634                                  0                                  0
# 47683                                   0                                  0
#
#         Function_Facilities Planning                 ...                  \
# 134338                             0                 ...
# 206341                             0                 ...
# 326408                             0                 ...
# 364634                             0                 ...
# 47683                              0                 ...
#
#         Object_Type_Rent/Utilities  Object_Type_Substitute Compensation  \
# 134338                           0                                    0
# 206341                           0                                    0
# 326408                           0                                    0
# 364634                           0                                    0
# 47683                            0                                    1
#
#         Object_Type_Supplies/Materials  Object_Type_Travel & Conferences  \
# 134338                               0                                 0
# 206341                               0                                 0
# 326408                               0                                 0
# 364634                               0                                 0
# 47683                                0                                 0
#
#         Pre_K_NO_LABEL  Pre_K_Non PreK  Pre_K_PreK  \
# 134338               1               0           0
# 206341               1               0           0
# 326408               0               1           0
# 364634               1               0           0
# 47683                1               0           0
#
#         Operating_Status_Non-Operating  \
# 134338                               0
# 206341                               1
# 326408                               0
# 364634                               0
# 47683                                0
#
#         Operating_Status_Operating, Not PreK-12  \
# 134338                                        0
# 206341                                        0
# 326408                                        0
# 364634                                        0
# 47683                                         0
#
#         Operating_Status_PreK-12 Operating
# 134338                                   1
# 206341                                   0
# 326408                                   1
# 364634                                   1
# 47683                                    1
#
# [5 rows x 104 columns]

# %%
df_label_dummies.shape
# Out:
# (400277, 104)

# %%
df_train[labels].shape
# Out:
# (400277, 9)

# %% [markdown]
# ** Doing the test-train split **
#
# Some labels don't occur very often, but we want to make sure that they appear in both the training and the test sets. A way to do this is using StratifiedShuffleSplit. However scikit-learn's StratifiedShuffleSplit works only for one target variable. Here we have 104 of them!
#
# To accomplish the stratified shuffle split for multiple target variable, I use the function written by [Peter Bull.](https://github.com/drivendataorg/box-plots-sklearn/blob/master/src/data/multilabel.py)

# %%
def multilabel_sample(y, size=1000, min_count=5, seed=None):
    """ Takes a matrix of binary labels `y` and returns
        the indices for a sample of size `size` if
        `size` > 1 or `size` * len(y) if size =< 1.
        The sample is guaranteed to have > `min_count` of
        each label.
    """
    try:
        if (np.unique(y).astype(int) != np.array([0, 1])).all():
            raise ValueError()
    except (TypeError, ValueError):
        raise ValueError('multilabel_sample only works with binary indicator matrices')

    if (y.sum(axis=0) < min_count).any():
        raise ValueError('Some classes do not have enough examples. Change min_count if necessary.')

    if size <= 1:
        size = np.floor(y.shape[0] * size)

    if y.shape[1] * min_count > size:
        msg = "Size less than number of columns * min_count, returning {} items instead of {}."
        warn(msg.format(y.shape[1] * min_count, size))
        size = y.shape[1] * min_count

    rng = np.random.RandomState(seed if seed is not None else np.random.randint(1))

    if isinstance(y, pd.DataFrame):
        choices = y.index
        y = y.values
    else:
        choices = np.arange(y.shape[0])

    sample_idxs = np.array([], dtype=choices.dtype)

    # first, guarantee > min_count of each label
    for j in range(y.shape[1]):
        label_choices = choices[y[:, j] == 1]
        label_idxs_sampled = rng.choice(label_choices, size=min_count, replace=False)
        sample_idxs = np.concatenate([label_idxs_sampled, sample_idxs])

    sample_idxs = np.unique(sample_idxs)

    # now that we have at least min_count of each, we can just random sample
    sample_count = int(size - sample_idxs.shape[0])

    # get sample_count indices from remaining choices
    remaining_choices = np.setdiff1d(choices, sample_idxs)
    remaining_sampled = rng.choice(remaining_choices,
                                   size=sample_count,
                                   replace=False)

    return np.concatenate([sample_idxs, remaining_sampled])


def multilabel_sample_dataframe(df, labels, size, min_count=5, seed=None):
    """ Takes a dataframe `df` and returns a sample of size `size` where all
        classes in the binary matrix `labels` are represented at
        least `min_count` times.
    """
    idxs = multilabel_sample(labels, size=size, min_count=min_count, seed=seed)
    return df.loc[idxs]


def multilabel_train_test_split(X, Y, size, min_count=5, seed=None):
    """ Takes a features matrix `X` and a label matrix `Y` and
        returns (X_train, X_test, Y_train, Y_test) where all
        classes in Y are represented at least `min_count` times.
    """
    index = Y.index if isinstance(Y, pd.DataFrame) else np.arange(Y.shape[0])

    test_set_idxs = multilabel_sample(Y, size=size, min_count=min_count, seed=seed)
    train_set_idxs = np.setdiff1d(index, test_set_idxs)

    test_set_mask = index.isin(test_set_idxs)
    train_set_mask = ~test_set_mask

    return (X[train_set_mask], X[test_set_mask], Y[train_set_mask], Y[test_set_mask])

# %% [markdown]
# The function multilabel_train_test_split() makes sure that at least min_count examples appear in each split.

# %%
X_train, X_test, y_train, y_test = multilabel_train_test_split(numeric_data,
                                                               df_label_dummies,
                                                               size=0.2, 
                                                               seed=123)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320222 entries, 134338 to 415831
# Data columns (total 2 columns):
# FTE      320222 non-null float64
# Total    320222 non-null float64
# dtypes: float64(2)
# memory usage: 7.3 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80055 entries, 206341 to 72072
# Data columns (total 2 columns):
# FTE      80055 non-null float64
# Total    80055 non-null float64
# dtypes: float64(2)
# memory usage: 1.8 MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320222 entries, 134338 to 415831
# Columns: 104 entries, Function_Aides Compensation to Operating_Status_PreK-12 Operating
# dtypes: uint8(104)
# memory usage: 34.2 MB

# %%
y_train.head()
# Out:
#         Function_Aides Compensation  Function_Career & Academic Counseling  \
# 134338                            0                                      0
# 326408                            0                                      0
# 364634                            0                                      0
# 47683                             0                                      0
# 229958                            0                                      0
#
#         Function_Communications  Function_Curriculum Development  \
# 134338                        0                                0
# 326408                        0                                0
# 364634                        0                                0
# 47683                         0                                0
# 229958                        0                                0
#
#         Function_Data Processing & Information Services  \
# 134338                                                0
# 326408                                                0
# 364634                                                0
# 47683                                                 0
# 229958                                                0
#
#         Function_Development & Fundraising  Function_Enrichment  \
# 134338                                   0                    0
# 326408                                   0                    0
# 364634                                   0                    0
# 47683                                    0                    0
# 229958                                   0                    0
#
#         Function_Extended Time & Tutoring  Function_Facilities & Maintenance  \
# 134338                                  0                                  0
# 326408                                  0                                  0
# 364634                                  0                                  0
# 47683                                   0                                  0
# 229958                                  0                                  1
#
#         Function_Facilities Planning                 ...                  \
# 134338                             0                 ...
# 326408                             0                 ...
# 364634                             0                 ...
# 47683                              0                 ...
# 229958                             0                 ...
#
#         Object_Type_Rent/Utilities  Object_Type_Substitute Compensation  \
# 134338                           0                                    0
# 326408                           0                                    0
# 364634                           0                                    0
# 47683                            0                                    1
# 229958                           0                                    0
#
#         Object_Type_Supplies/Materials  Object_Type_Travel & Conferences  \
# 134338                               0                                 0
# 326408                               0                                 0
# 364634                               0                                 0
# 47683                                0                                 0
# 229958                               0                                 0
#
#         Pre_K_NO_LABEL  Pre_K_Non PreK  Pre_K_PreK  \
# 134338               1               0           0
# 326408               0               1           0
# 364634               1               0           0
# 47683                1               0           0
# 229958               1               0           0
#
#         Operating_Status_Non-Operating  \
# 134338                               0
# 326408                               0
# 364634                               0
# 47683                                0
# 229958                               0
#
#         Operating_Status_Operating, Not PreK-12  \
# 134338                                        0
# 326408                                        0
# 364634                                        0
# 47683                                         0
# 229958                                        0
#
#         Operating_Status_PreK-12 Operating
# 134338                                   1
# 326408                                   1
# 364634                                   1
# 47683                                    1
# 229958                                   1
#
# [5 rows x 104 columns]

# %%
y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80055 entries, 206341 to 72072
# Columns: 104 entries, Function_Aides Compensation to Operating_Status_PreK-12 Operating
# dtypes: uint8(104)
# memory usage: 8.6 MB

# %% [markdown]
# Training Model

# %%
clf = OneVsRestClassifier(LogisticRegression())
clf.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1)

# %% [markdown]
# OneVsRestClassifier treats each columns of y independently. Essentially, it fits a separate classifier for each of the columns.

# %%
clf.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# Pretty dismal score. But not very surprising given that we threw out most of our data. Let's go ahead and test the predictions on the holdout test data. Note that because we are developing 'human-in-the-loop' system, we wanna output the probabilities.

# %%
holdout = pd.read_csv('TestData.csv', index_col=0)
# Out:
# /Users/sushantmore/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
holdout.head()
# Out:
#                     Object_Description         Program_Description  \
# 180042        Student Meals/Room/Other  Basic Educational Services
# 28872     Extra Duty/Signing Bonus Pay               Undistributed
# 186915           Professional Salaries         Bilingual Education
# 412396           Professional Salaries         Bilingual Education
# 427740  Salaries for Support Personnel               Undistributed
#
#        SubFund_Description Job_Title_Description Facility_or_Department  \
# 180042                 NaN                   NaN                    NaN
# 28872                  NaN       CHEERLEADER DIR                    NaN
# 186915                 NaN          T-EL 1ST BIL                    NaN
# 412396                 NaN          T-EL 2ND BIL                    NaN
# 427740                 NaN        CLERK III- SCH                    NaN
#
#                            Sub_Object_Description Location_Description  FTE  \
# 180042  Line Item that is paid with Campus' money              School   NaN
# 28872                                     General              School   NaN
# 186915                                    General              School   1.0
# 412396                                    General              School   1.0
# 427740                                    General              School   1.0
#
#                               Function_Description Position_Extra Text_4  \
# 180042                                 Instruction            NaN    NaN
# 28872   Cocurricular & Extra Curricular Activities            NaN    NaN
# 186915                                 Instruction            NaN    NaN
# 412396                                 Instruction            NaN    NaN
# 427740                           School Leadership            NaN    NaN
#
#                Total Text_2 Text_3 Fund_Description Text_1
# 180042   3999.910000    NaN    NaN     General Fund    NaN
# 28872    3447.320213    NaN    NaN     General Fund    NaN
# 186915  52738.780869    NaN    NaN     General Fund    NaN
# 412396  69729.263191    NaN    NaN     General Fund    NaN
# 427740  29492.834215    NaN    NaN     General Fund    NaN

# %%
prediction = clf.predict_proba(holdout[numeric_columns].fillna(-1000))
# Out:
# /Users/sushantmore/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)

# %%
prediction
# Out:
# array([[3.58422797e-02, 6.46624380e-03, 8.29889897e-04, ...,
#         1.69612505e-01, 1.99296715e-02, 8.10542978e-01],
#        [3.58482728e-02, 6.46610323e-03, 8.29901972e-04, ...,
#         1.69607062e-01, 1.99300220e-02, 8.10552526e-01],
#        [1.20946821e-01, 9.06524483e-03, 1.58707950e-03, ...,
#         9.59309999e-02, 5.10388042e-02, 9.28360476e-01],
#        ...,
#        [1.22222570e-01, 9.05171601e-03, 1.58866973e-03, ...,
#         9.57003802e-02, 5.10986945e-02, 9.28644820e-01],
#        [1.22275131e-01, 9.04889685e-03, 1.58830780e-03, ...,
#         9.57066370e-02, 5.10808770e-02, 9.28635308e-01],
#        [1.22159718e-01, 9.05011410e-03, 1.58816455e-03, ...,
#         9.57273883e-02, 5.10754822e-02, 9.28609739e-01]])

# %%
prediction.shape
# Out:
# (50064, 104)

# %%
holdout.shape
# Out:
# (50064, 16)

# %%
df_train.shape
# Out:
# (400277, 25)

# %% [markdown]
# Note 25 - 16 = 9. We have 9 taget variables (before applying the get_dummies).

# %% [markdown]
# Let's write predictions to a dataframe

# %%
prediction_df = pd.DataFrame(data = prediction, columns=pd.get_dummies(df_train[labels]).columns, \
                            index = holdout.index)

# %%
prediction_df.head()
# Out:
#         Function_Aides Compensation  Function_Career & Academic Counseling  \
# 180042                     0.035842                               0.006466
# 28872                      0.035848                               0.006466
# 186915                     0.120947                               0.009065
# 412396                     0.120381                               0.009071
# 427740                     0.121725                               0.009057
#
#         Function_Communications  Function_Curriculum Development  \
# 180042                 0.000830                         0.023918
# 28872                  0.000830                         0.023919
# 186915                 0.001587                         0.028599
# 412396                 0.001586                         0.028573
# 427740                 0.001588                         0.028634
#
#         Function_Data Processing & Information Services  \
# 180042                                         0.008916
# 28872                                          0.008916
# 186915                                         0.016042
# 412396                                         0.016044
# 427740                                         0.016038
#
#         Function_Development & Fundraising  Function_Enrichment  \
# 180042                            0.000147             0.032077
# 28872                             0.000147             0.032078
# 186915                            0.056023             0.043858
# 412396                            0.055813             0.043808
# 427740                            0.056310             0.043926
#
#         Function_Extended Time & Tutoring  Function_Facilities & Maintenance  \
# 180042                           0.024406                           0.052099
# 28872                            0.024406                           0.052102
# 186915                           0.031715                           0.113907
# 412396                           0.031688                           0.113723
# 427740                           0.031752                           0.114158
#
#         Function_Facilities Planning                 ...                  \
# 180042                      0.000069                 ...
# 28872                       0.000069                 ...
# 186915                      0.017065                 ...
# 412396                      0.017034                 ...
# 427740                      0.017107                 ...
#
#         Object_Type_Rent/Utilities  Object_Type_Substitute Compensation  \
# 180042                    0.010729                             0.036846
# 28872                     0.010728                             0.036959
# 186915                    0.005622                             0.136221
# 412396                    0.005630                             0.125189
# 427740                    0.005612                             0.152629
#
#         Object_Type_Supplies/Materials  Object_Type_Travel & Conferences  \
# 180042                        0.116126                          0.017360
# 28872                         0.116164                          0.017361
# 186915                        0.135391                          0.016041
# 412396                        0.134056                          0.016029
# 427740                        0.137236                          0.016058
#
#         Pre_K_NO_LABEL  Pre_K_Non PreK  Pre_K_PreK  \
# 180042        0.831241        0.141031    0.027749
# 28872         0.831233        0.141041    0.027751
# 186915        0.501655        0.472173    0.098601
# 412396        0.502143        0.471525    0.098399
# 427740        0.500987        0.473061    0.098879
#
#         Operating_Status_Non-Operating  \
# 180042                        0.169613
# 28872                         0.169607
# 186915                        0.095931
# 412396                        0.096034
# 427740                        0.095790
#
#         Operating_Status_Operating, Not PreK-12  \
# 180042                                 0.019930
# 28872                                  0.019930
# 186915                                 0.051039
# 412396                                 0.051012
# 427740                                 0.051075
#
#         Operating_Status_PreK-12 Operating
# 180042                            0.810543
# 28872                             0.810553
# 186915                            0.928360
# 412396                            0.928233
# 427740                            0.928534
#
# [5 rows x 104 columns]

# %% [markdown]
# Notice how we have probabilities for each column.

# %%
df_train.head()
# Out:
#                        Function          Use          Sharing Reporting  \
# 134338     Teacher Compensation  Instruction  School Reported    School
# 206341                 NO_LABEL     NO_LABEL         NO_LABEL  NO_LABEL
# 326408     Teacher Compensation  Instruction  School Reported    School
# 364634  Substitute Compensation  Instruction  School Reported    School
# 47683   Substitute Compensation  Instruction  School Reported    School
#
#        Student_Type Position_Type               Object_Type     Pre_K  \
# 134338     NO_LABEL       Teacher                  NO_LABEL  NO_LABEL
# 206341     NO_LABEL      NO_LABEL                  NO_LABEL  NO_LABEL
# 326408  Unspecified       Teacher  Base Salary/Compensation  Non PreK
# 364634  Unspecified    Substitute                  Benefits  NO_LABEL
# 47683   Unspecified       Teacher   Substitute Compensation  NO_LABEL
#
#          Operating_Status            Object_Description  \
# 134338  PreK-12 Operating                           NaN
# 206341      Non-Operating           CONTRACTOR SERVICES
# 326408  PreK-12 Operating  Personal Services - Teachers
# 364634  PreK-12 Operating             EMPLOYEE BENEFITS
# 47683   PreK-12 Operating  TEACHER COVERAGE FOR TEACHER
#
#                     ...               Sub_Object_Description  \
# 134338              ...                                  NaN
# 206341              ...                                  NaN
# 326408              ...                                  NaN
# 364634              ...                                  NaN
# 47683               ...                                  NaN
#
#        Location_Description  FTE     Function_Description  \
# 134338                  NaN  1.0                      NaN
# 206341                  NaN  NaN                 RGN  GOB
# 326408                  NaN  1.0                      NaN
# 364634                  NaN  NaN  UNALLOC BUDGETS/SCHOOLS
# 47683                   NaN  NaN              NON-PROJECT
#
#        Facility_or_Department              Position_Extra      Total  \
# 134338                    NaN               KINDERGARTEN   50471.810
# 206341                    NaN                UNDESIGNATED   3477.860
# 326408                    NaN                     TEACHER  62237.130
# 364634                    NaN  PROFESSIONAL-INSTRUCTIONAL     22.300
# 47683                     NaN  PROFESSIONAL-INSTRUCTIONAL     54.166
#
#                    Program_Description        Fund_Description  \
# 134338                    KINDERGARTEN            General Fund
# 206341   BUILDING IMPROVEMENT SERVICES                     NaN
# 326408           Instruction - Regular  General Purpose School
# 364634  GENERAL MIDDLE/JUNIOR HIGH SCH                     NaN
# 47683    GENERAL HIGH SCHOOL EDUCATION                     NaN
#
#                                Text_1
# 134338                            NaN
# 206341  BUILDING IMPROVEMENT SERVICES
# 326408                            NaN
# 364634            REGULAR INSTRUCTION
# 47683             REGULAR INSTRUCTION
#
# [5 rows x 25 columns]

# %%
df_train['Position_Extra']
# Out:
# 134338                    KINDERGARTEN
# 206341                     UNDESIGNATED
# 326408                          TEACHER
# 364634       PROFESSIONAL-INSTRUCTIONAL
# 47683        PROFESSIONAL-INSTRUCTIONAL
# 229958                     UNDESIGNATED
# 417668           SUPPLIES AND MATERIALS
# 126378                     UNDESIGNATED
# 275539       PROFESSIONAL-INSTRUCTIONAL
# 85262        PROFESSIONAL-INSTRUCTIONAL
# 304569                              NaN
# 330504                              NaN
# 84272                           TEACHER
# 64760                               NaN
# 21870                               NaN
# 18698                DEGREED SUBSTITUTE
# 169454                              NaN
# 169914                              NaN
# 189701                     UNDESIGNATED
# 43727                               NaN
# 5614                                NaN
# 291539       PROFESSIONAL-INSTRUCTIONAL
# 307038                              NaN
# 27645                               NaN
# 126388               SUBSTITUTE TEACHER
# 14962                   TEACHER -  DAYS
# 84040                               NaN
# 61639        PROFESSIONAL-INSTRUCTIONAL
# 266302       PROFESSIONAL-INSTRUCTIONAL
# 225768                       BUS DRIVER
#                       ...
# 333748                              NaN
# 292626           DIR EXEC DIR SECRETARY
# 343458       PROFESSIONAL-INSTRUCTIONAL
# 128261       PROFESSIONAL-INSTRUCTIONAL
# 186318       PROFESSIONAL-INSTRUCTIONAL
# 210652               SUBSTITUTE TEACHER
# 340354                 PARAPROFESSIONAL
# 435205       PROFESSIONAL-INSTRUCTIONAL
# 174827                 PARAPROFESSIONAL
# 277504                     UNDESIGNATED
# 248062                              NaN
# 70455                               NaN
# 203453                              NaN
# 58170                SUBSTITUTE TEACHER
# 72072                    ASST PRINCIPAL
# 68311        PROFESSIONAL-INSTRUCTIONAL
# 225892       PROFESSIONAL-INSTRUCTIONAL
# 446383                              NaN
# 155111       RADIO & SUBSTITUTE DRIVERS
# 278248                              NaN
# 397424                 PARAPROFESSIONAL
# 375092               SUBSTITUTE TEACHER
# 220181         REG FOOD SERVICE WORKER
# 307423                              NaN
# 46691        PROFESSIONAL-INSTRUCTIONAL
# 109283                              NaN
# 102430       PROFESSIONAL-INSTRUCTIONAL
# 413949                   PARENT/TITLE I
# 433672    OFFICE/ADMINISTRATIVE SUPPORT
# 415831             CERTIFIED SUBSTITUTE
# Name: Position_Extra, Length: 400277, dtype: object

# %% [markdown]
# ### Getting started on NLP
#
# #### The first thing to do is create a bag of words
#
# Let's start by creating bag of words for just one feature 'Position_Extra'. We split the token on alpha numerics. Before doing that we fill the NaNs with empy strings.

# %%
df_train['Position_Extra'].fillna('', inplace = True)

# %%
TOKEN_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)'

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
class LemmaTokenizer(object):
    def __init__(self):
         self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %%
# Instantiate the CountVectorizer: vec_alphanumeric
vec_alphanumeric = CountVectorizer(token_pattern = TOKEN_ALPHANUMERIC, stop_words='english', tokenizer=LemmaTokenizer())

# %%
vec_alphanumeric.fit(df_train['Position_Extra'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='[A-Za-z0-9]+(?=\\s+)',
#         tokenizer=<__main__.LemmaTokenizer object at 0x1308d78d0>,
#         vocabulary=None)

# %%
vec_alphanumeric.get_feature_names()
# Out:
# ['1st',
#  '2nd',
#  '3rd',
#  '4th',
#  '56',
#  '5th',
#  '9th',
#  'ab',
#  'accountability',
#  'adaptive',
#  'addit',
#  'additional',
#  'adm',
#  'admin',
#  'administrative',
#  'adult',
#  'aide',
#  'air',
#  'alarm',
#  'alt',
#  'area',
#  'arra',
#  'art',
#  'arts',
#  'assessment',
#  'assistant',
#  'assistive',
#  'asst',
#  'athletic',
#  'attendance',
#  'attn',
#  'audiology',
#  'auto',
#  'avg',
#  'aviation',
#  'ayp',
#  'b',
#  'behavior',
#  'behavioral',
#  'bilingual',
#  'biology',
#  'bldg',
#  'blind',
#  'board',
#  'broadcast',
#  'building',
#  'buildings',
#  'bus',
#  'business',
#  'cafe',
#  'camera',
#  'campbell',
#  'campus',
#  'card',
#  'career',
#  'case',
#  'ccoach',
#  'cen',
#  'center',
#  'central',
#  'cert',
#  'certified',
#  'change',
#  'chemistry',
#  'chief',
#  'child',
#  'chinese',
#  'classified',
#  'clerk',
#  'clinic',
#  'cntrl',
#  'coach',
#  'college',
#  'communication',
#  'computer',
#  'condition',
#  'consultant',
#  'consumer',
#  'cont',
#  'contractual',
#  'correctionist',
#  'cosmetology',
#  'counselor',
#  'criminal',
#  'crossing',
#  'culinary',
#  'curr',
#  'curriculum',
#  'cus',
#  'cust',
#  'custodial',
#  'custodian',
#  'dance',
#  'data',
#  'days',
#  'deaf',
#  'degreed',
#  'department',
#  'depty',
#  'deputy',
#  'dir',
#  'director',
#  'disabilities',
#  'disorder',
#  'dispatcher',
#  'distributed',
#  'domestic',
#  'drama',
#  'driver',
#  'e',
#  'earth',
#  'ec',
#  'economics',
#  'ed',
#  'educ',
#  'education',
#  'educational',
#  'elem',
#  'empac',
#  'employee',
#  'eng',
#  'engineer',
#  'english',
#  'equip',
#  'es',
#  'esl',
#  'exec',
#  'executive',
#  'exploration',
#  'ext',
#  'facilitator',
#  'field',
#  'financial',
#  'fix',
#  'fixed',
#  'food',
#  'foods',
#  'foreman',
#  'french',
#  'fs',
#  'fsd',
#  'gen',
#  'general',
#  'generalist',
#  'geography',
#  'german',
#  'gifted',
#  'gnets',
#  'grade',
#  'graduation',
#  'graphic',
#  'grease',
#  'gross',
#  'guard',
#  'guidance',
#  'handicapped',
#  'head',
#  'health',
#  'hearing',
#  'heavy',
#  'high',
#  'history',
#  'home',
#  'homebound',
#  'horticulture',
#  'hospital',
#  'hourly',
#  'hr',
#  'hrly',
#  'hs',
#  'impaired',
#  'information',
#  'instruc',
#  'instruct',
#  'instructional',
#  'instrumental',
#  'inter',
#  'intermediate',
#  'intern',
#  'interpreter',
#  'interrelated',
#  'intervention',
#  'intr',
#  'intructional',
#  'iss',
#  'janitorial',
#  'japanese',
#  'job',
#  'jr',
#  'justice',
#  'k',
#  'kdg',
#  'kindergarten',
#  'ladder',
#  'lang',
#  'large',
#  'latin',
#  'lead',
#  'leadman',
#  'learning',
#  'librarian',
#  'licensed',
#  'lieutenant',
#  'life',
#  'literacy',
#  'mailroom',
#  'maintenance',
#  'man',
#  'manager',
#  'marketing',
#  'math',
#  'mechanic',
#  'mechanics',
#  'med',
#  'media',
#  'mental',
#  'mentally',
#  'mgr',
#  'mid',
#  'middle',
#  'mildly',
#  'minor',
#  'misc',
#  'mo',
#  'moderate',
#  'months',
#  'ms',
#  'music',
#  'nc',
#  'needs',
#  'network',
#  'night',
#  'non',
#  'nurse',
#  'occupancy',
#  'occupational',
#  'occupations',
#  'office',
#  'officer',
#  'oil',
#  'operating',
#  'operation',
#  'optional',
#  'orthopedically',
#  'overtime',
#  'pac',
#  'painter',
#  'para',
#  'paraprof',
#  'parent',
#  'partially',
#  'patrol',
#  'pay',
#  'payroll',
#  'pe',
#  'phys',
#  'physical',
#  'physics',
#  'police',
#  'political',
#  'primary',
#  'prin',
#  'principal',
#  'print',
#  'proc',
#  'production',
#  'prof',
#  'professional',
#  'program',
#  'programmer',
#  'property',
#  'psych',
#  'psychological',
#  'psychologist',
#  'public',
#  'pump',
#  'purchased',
#  'radio',
#  'reading',
#  'rec',
#  'receives',
#  'referral',
#  'reg',
#  'regular',
#  'repair',
#  'reqd',
#  'resource',
#  'retarded',
#  'retiree',
#  'rotc',
#  'router',
#  'sac',
#  'sal',
#  'sales',
#  'sasi',
#  'sat',
#  'sch',
#  'school',
#  'science',
#  'sec',
#  'secondary',
#  'secretary',
#  'security',
#  'self',
#  'senior',
#  'service',
#  'services',
#  'severely',
#  'shop',
#  'sighted',
#  'site',
#  'size',
#  'small',
#  'social',
#  'solutions',
#  'sp',
#  'spanish',
#  'spec',
#  'special',
#  'specialist',
#  'speech',
#  'sr',
#  'staff',
#  'start',
#  'structured',
#  'sub',
#  'subsidies',
#  'substitute',
#  'summer',
#  'super',
#  'supervisor',
#  'supplies',
#  'supply',
#  'support',
#  'supt',
#  'systems',
#  'talented',
#  'tap',
#  'teacher',
#  'teachers',
#  'team',
#  'tech',
#  'technical',
#  'technician',
#  'technicians',
#  'technology',
#  'telecommunication',
#  'temp',
#  'temporary',
#  'textbook',
#  'therapist',
#  'therapy',
#  'time',
#  'title',
#  'train',
#  'transition',
#  'transportation',
#  'travel',
#  'traveling',
#  'trip',
#  'truck',
#  'tv',
#  'used',
#  'visual',
#  'vocational',
#  'voe',
#  'warehouse',
#  'web',
#  'wkr',
#  'worker']

# %%
vec_alphanumeric.get_feature_names()
# Out:
# ['1st',
#  '2nd',
#  '3rd',
#  '4th',
#  '56',
#  '5th',
#  '9th',
#  'a',
#  'ab',
#  'accountability',
#  'adaptive',
#  'addit',
#  'additional',
#  'adm',
#  'admin',
#  'administrative',
#  'adult',
#  'aide',
#  'air',
#  'alarm',
#  'alt',
#  'and',
#  'any',
#  'area',
#  'arra',
#  'art',
#  'arts',
#  'assessment',
#  'assistant',
#  'assistive',
#  'asst',
#  'at',
#  'athletic',
#  'attendance',
#  'attn',
#  'audiology',
#  'auto',
#  'avg',
#  'aviation',
#  'ayp',
#  'b',
#  'behavior',
#  'behavioral',
#  'bilingual',
#  'biology',
#  'bldg',
#  'blind',
#  'board',
#  'broadcast',
#  'building',
#  'buildings',
#  'bus',
#  'business',
#  'cafe',
#  'camera',
#  'campbell',
#  'campus',
#  'card',
#  'career',
#  'case',
#  'ccoach',
#  'cen',
#  'center',
#  'central',
#  'cert',
#  'certified',
#  'change',
#  'chemistry',
#  'chief',
#  'child',
#  'chinese',
#  'classified',
#  'clerk',
#  'clinic',
#  'cntrl',
#  'co',
#  'coach',
#  'college',
#  'communication',
#  'computer',
#  'condition',
#  'consultant',
#  'consumer',
#  'cont',
#  'contractual',
#  'correctionist',
#  'cosmetology',
#  'counselor',
#  'criminal',
#  'crossing',
#  'culinary',
#  'curr',
#  'curriculum',
#  'cus',
#  'cust',
#  'custodial',
#  'custodian',
#  'dance',
#  'data',
#  'days',
#  'deaf',
#  'degreed',
#  'department',
#  'depty',
#  'deputy',
#  'dir',
#  'director',
#  'disabilities',
#  'disorder',
#  'dispatcher',
#  'distributed',
#  'domestic',
#  'drama',
#  'driver',
#  'e',
#  'earth',
#  'ec',
#  'economics',
#  'ed',
#  'educ',
#  'education',
#  'educational',
#  'elem',
#  'empac',
#  'employee',
#  'eng',
#  'engineer',
#  'english',
#  'equip',
#  'es',
#  'esl',
#  'exec',
#  'executive',
#  'exploration',
#  'ext',
#  'facilitator',
#  'field',
#  'financial',
#  'fix',
#  'fixed',
#  'food',
#  'foods',
#  'for',
#  'foreman',
#  'french',
#  'fs',
#  'fsd',
#  'full',
#  'gen',
#  'general',
#  'generalist',
#  'geography',
#  'german',
#  'gifted',
#  'gnets',
#  'grade',
#  'graduation',
#  'graphic',
#  'grease',
#  'gross',
#  'guard',
#  'guidance',
#  'handicapped',
#  'head',
#  'health',
#  'hearing',
#  'heavy',
#  'high',
#  'history',
#  'home',
#  'homebound',
#  'horticulture',
#  'hospital',
#  'hourly',
#  'hr',
#  'hrly',
#  'hs',
#  'i',
#  'impaired',
#  'information',
#  'instruc',
#  'instruct',
#  'instructional',
#  'instrumental',
#  'inter',
#  'intermediate',
#  'intern',
#  'interpreter',
#  'interrelated',
#  'intervention',
#  'intr',
#  'intructional',
#  'is',
#  'iss',
#  'janitorial',
#  'japanese',
#  'job',
#  'jr',
#  'justice',
#  'k',
#  'kdg',
#  'kindergarten',
#  'ladder',
#  'lang',
#  'large',
#  'latin',
#  'lead',
#  'leadman',
#  'learning',
#  'librarian',
#  'licensed',
#  'lieutenant',
#  'life',
#  'literacy',
#  'mailroom',
#  'maintenance',
#  'man',
#  'manager',
#  'marketing',
#  'math',
#  'mechanic',
#  'mechanics',
#  'med',
#  'media',
#  'mental',
#  'mentally',
#  'mgr',
#  'mid',
#  'middle',
#  'mildly',
#  'minor',
#  'misc',
#  'mo',
#  'moderate',
#  'months',
#  'ms',
#  'music',
#  'nc',
#  'needs',
#  'network',
#  'night',
#  'no',
#  'non',
#  'none',
#  'not',
#  'nurse',
#  'occupancy',
#  'occupational',
#  'occupations',
#  'of',
#  'office',
#  'officer',
#  'oil',
#  'operating',
#  'operation',
#  'optional',
#  'orthopedically',
#  'other',
#  'overtime',
#  'pac',
#  'painter',
#  'para',
#  'paraprof',
#  'parent',
#  'partially',
#  'patrol',
#  'pay',
#  'payroll',
#  'pe',
#  'phys',
#  'physical',
#  'physics',
#  'police',
#  'political',
#  'primary',
#  'prin',
#  'principal',
#  'print',
#  'proc',
#  'production',
#  'prof',
#  'professional',
#  'program',
#  'programmer',
#  'property',
#  'psych',
#  'psychological',
#  'psychologist',
#  'public',
#  'pump',
#  'purchased',
#  'radio',
#  'reading',
#  'rec',
#  'receives',
#  'referral',
#  'reg',
#  'regular',
#  'repair',
#  'reqd',
#  'resource',
#  'retarded',
#  'retiree',
#  'rotc',
#  'router',
#  'sac',
#  'sal',
#  'sales',
#  'sasi',
#  'sat',
#  'sch',
#  'school',
#  'science',
#  'sec',
#  'secondary',
#  'secretary',
#  'security',
#  'self',
#  'senior',
#  'service',
#  'services',
#  'severely',
#  'shop',
#  'sighted',
#  'site',
#  'size',
#  'small',
#  'social',
#  'solutions',
#  'sp',
#  'spanish',
#  'spec',
#  'special',
#  'specialist',
#  'speech',
#  'sr',
#  'staff',
#  'start',
#  'structured',
#  'sub',
#  'subsidies',
#  'substitute',
#  'summer',
#  'super',
#  'supervisor',
#  'supplies',
#  'supply',
#  'support',
#  'supt',
#  'systems',
#  'talented',
#  'tap',
#  'teacher',
#  'teachers',
#  'team',
#  'tech',
#  'technical',
#  'technician',
#  'technicians',
#  'technology',
#  'telecommunication',
#  'temp',
#  'temporary',
#  'textbook',
#  'therapist',
#  'therapy',
#  'time',
#  'title',
#  'train',
#  'transition',
#  'transportation',
#  'travel',
#  'traveling',
#  'trip',
#  'truck',
#  'tv',
#  'used',
#  'visual',
#  'vocational',
#  'voe',
#  'warehouse',
#  'web',
#  'who',
#  'wkr',
#  'worker']

# %%
vec_alphanumeric.get_feature_names()
# Out:
# ['&',
#  '(',
#  ')',
#  ',',
#  '-',
#  '-2nd',
#  '.',
#  '1st',
#  '2nd',
#  '3rd',
#  '4th',
#  '56',
#  '5th',
#  '9th',
#  'ab',
#  'accountability',
#  'accountant',
#  'adaptive',
#  'addit',
#  'additional',
#  'addl',
#  'adm',
#  'admin',
#  'administrative',
#  'administrator',
#  'adult',
#  'aide',
#  'air',
#  'alarm',
#  'allotment',
#  'alt',
#  'analyst',
#  'anlayst',
#  'area',
#  'arra',
#  'art',
#  'assessment',
#  'asset',
#  'assistant',
#  'assistive',
#  'asst',
#  'asst-sp',
#  'athletic',
#  'attendance',
#  'attn',
#  'audiologist',
#  'audiology',
#  'auto',
#  'avg',
#  'aviation',
#  'ayp',
#  'b',
#  'bachelor',
#  'behavior',
#  'behavioral',
#  'bilingual',
#  'biology',
#  'birth/kind',
#  'bldg',
#  'blind',
#  'bnc-supervisor',
#  'board',
#  'bookkeeper',
#  'broadcast',
#  'building',
#  'building/property',
#  'bus',
#  'business',
#  'cafe',
#  'camera',
#  'campbell',
#  'campus',
#  'card',
#  'career',
#  'case',
#  'ccoach',
#  'cen',
#  'center',
#  'central',
#  'cert',
#  'certified',
#  'certifiedaddl',
#  'change',
#  'charge',
#  'chef',
#  'chemistry',
#  'chief',
#  'child',
#  'chinese',
#  'classified',
#  'clerical',
#  'clerical/bookkeeper',
#  'clerk',
#  'clinic',
#  'co-dispatcher',
#  'co-tchr',
#  'coach',
#  'college',
#  'comm',
#  'communication',
#  'computer',
#  'condition',
#  'const.sec.',
#  'consultant',
#  'cont',
#  'containd',
#  'contained',
#  'contract',
#  'contractual',
#  'corporal',
#  'correctionist',
#  'cosmetology',
#  'cost',
#  'counselor',
#  'craft',
#  'criminal',
#  'crossing',
#  'cti',
#  'cu',
#  'culinary',
#  'curr',
#  'curriculum',
#  'cust',
#  'custodial',
#  'custodian',
#  'dance',
#  'data',
#  'day',
#  'deaf',
#  'degreed',
#  'department',
#  'dept',
#  'depty',
#  'deputy',
#  'design',
#  'development',
#  'diagnostician',
#  'dietician',
#  'dir',
#  'director',
#  'directr',
#  'disability',
#  'disorder',
#  'dispatcher',
#  'distributed',
#  'doctoral',
#  'domestic',
#  'drama',
#  'driver',
#  'e',
#  'earth',
#  'ec',
#  'economics',
#  'ed',
#  'ed-arra',
#  'ed-gnets',
#  'ed-speech',
#  'educ',
#  'education',
#  'educational',
#  'eip-intermediate',
#  'eip-kindergarten',
#  'eip-primary',
#  'elem',
#  'elem/inter',
#  'elem/interm',
#  'elem/intermediate',
#  'elementary',
#  'empac',
#  'employee',
#  'energy',
#  'eng',
#  'engineer',
#  'engineering',
#  'english',
#  'equip',
#  'equp',
#  'esl',
#  'esol',
#  'examiner',
#  'exec',
#  'executive',
#  'exploration',
#  'f',
#  'facilitator',
#  'family/consumer',
#  'field',
#  'financial',
#  'fix',
#  'fixed',
#  'flat',
#  'food',
#  'foreman',
#  'french',
#  'fsd',
#  'gen',
#  'general',
#  'generalist',
#  'geography',
#  'german',
#  'gifted',
#  'grade',
#  'graduation',
#  'graphic',
#  'grease',
#  'gross',
#  'guard',
#  'guidance',
#  'h',
#  'handicapped',
#  'head',
#  'health',
#  'hearing',
#  'heavy',
#  'high',
#  'history',
#  'home',
#  'homebound',
#  'homeless',
#  'horticulture',
#  'hospital',
#  'hourly',
#  'hr',
#  'hrly',
#  'i/ext',
#  'ii/ext',
#  'iii/ext',
#  'impaired',
#  'information',
#  'inspector',
#  'instruc',
#  'instruct',
#  'instruction',
#  'instructional',
#  'instructor',
#  'instrumental',
#  'inter',
#  'intern',
#  'interpreter',
#  'interrelated',
#  'intervention',
#  'intr',
#  'intrn',
#  'intructional',
#  'janitorial',
#  'japanese',
#  'job',
#  'jr',
#  'justice',
#  'kdg',
#  'kindergarten',
#  'labor',
#  'ladder',
#  'lang',
#  'large',
#  'latin',
#  'lead',
#  'leadman',
#  'learning',
#  'liason',
#  'librarian',
#  'licensed',
#  'lieutenant',
#  'life',
#  'literacy',
#  'lpn',
#  'm',
#  'mailroom',
#  'maintenance',
#  'man',
#  'manager',
#  'manager/liason',
#  'marketing',
#  'master',
#  'material',
#  'math',
#  'mechanic',
#  'med',
#  'medium',
#  'member',
#  'mental',
#  'mentally',
#  'mentor',
#  'mgr',
#  'mid',
#  'middle',
#  'mildly',
#  'minor',
#  'misc',
#  'mo',
#  'moderate',
#  'mon',
#  'mon-n/cert',
#  'monitor',
#  'month',
#  'music',
#  'n-faculty',
#  'n/c',
#  'nc',
#  'ncert',
#  'need',
#  'network',
#  'night',
#  'non',
#  'non-degreed',
#  'noncert',
#  'nurse',
#  'nutritionist',
#  'occupancy',
#  'occupation',
#  'occupational',
#  'occupational/physical',
#  'office',
#  'office/administrative',
#  'officer',
#  'oil',
#  'operating',
#  'operation',
#  'operator',
#  'optional',
#  'orthopedically',
#  'overtime',
#  'pac',
#  'painter',
#  'para',
#  'paraprof',
#  'paraprofessional',
#  'parent',
#  'parent/title',
#  'partially',
#  'patrol',
#  'pay',
#  'payroll',
#  'pe',
#  'phys',
#  'physic',
#  'physical',
#  'police',
#  'political',
#  'pos.cntrl',
#  'pre-k',
#  'pre-referral',
#  'prin',
#  'principal',
#  'print',
#  'proc',
#  'processing',
#  'production',
#  'prof',
#  'professional',
#  'professional-instructional',
#  'professional-other',
#  'program',
#  'programmer',
#  'psy',
#  'psych',
#  'psychological',
#  'psychologist',
#  'public',
#  'pump',
#  'purchased',
#  'radio',
#  'radio/tv',
#  'rate',
#  'reading',
#  'rec',
#  'receives',
#  'receiving',
#  'reg',
#  'registrar',
#  'regular',
#  'rental',
#  'rentals-land',
#  'repair',
#  'reqd',
#  'resource',
#  'retarded',
#  'retiree',
#  'rotc',
#  'router',
#  's.e',
#  'sac',
#  'sal',
#  'salaried',
#  'sale',
#  'sasi',
#  'sat',
#  'sch',
#  'sched',
#  'school',
#  'science',
#  'scrty',
#  'sec',
#  'secondary',
#  'secretary',
#  'security',
#  'sel-contained',
#  'self',
#  'senior',
#  'sergeant',
#  'service',
#  'severely',
#  'shift',
#  'shop',
#  'sighted',
#  'site',
#  'size',
#  'slp',
#  'small',
#  'social',
#  'solution',
#  'spanish',
#  'spec',
#  'special',
#  'specialist',
#  'speech',
#  'sr',
#  'sr.',
#  'staff',
#  'start',
#  'structure',
#  'structured',
#  'student',
#  'sub',
#  'subsidy',
#  'substitute',
#  'super',
#  'superintendent',
#  'supervisor',
#  'suppl',
#  'supply',
#  'support',
#  'supt',
#  'supv',
#  'ta',
#  'talented',
#  'tap',
#  'tchracct',
#  'teacher',
#  'team',
#  'tech',
#  'technical',
#  'technician',
#  'technology',
#  'telecommunication',
#  'telegram',
#  'telephone',
#  'teletype',
#  'temp',
#  'temp-summer',
#  'temporary',
#  'textbook',
#  'therapist',
#  'therapy',
#  'therp',
#  'time',
#  'timecard',
#  'trade',
#  'train',
#  'transfer',
#  'transition',
#  'transportation',
#  'travel',
#  'traveling',
#  'trip',
#  'truck',
#  'tutoring',
#  'undesignated',
#  'video',
#  'visual',
#  'voc',
#  'vocational',
#  'voe',
#  'w/doctorate',
#  'warehouse',
#  'web',
#  'wkr',
#  'worke',
#  'worker',
#  'wrk',
#  'wrong-used']

# %%
len(vec_alphanumeric.get_feature_names()) # vanilla version CountTokenizer()
# Out:
# 385

# %%
len(vec_alphanumeric.get_feature_names()) # Using stop words
# Out:
# 370

# %%
len(vec_alphanumeric.get_feature_names()) # Using LemmaTokenizer()
# Out:
# 481

# %%
type(vec_alphanumeric.get_feature_names())
# Out:
# list

# %%
LABELS = labels
NUMERIC_COLUMNS = numeric_columns

# %% [markdown]
# In order to get a bag-of-words representation for all of the text data in our DataFrame, we must first convert the text data in each row of the DataFrame into a single string.
#
# We proceed to do so by grabbing all the data from columns which are not numeric or label data and then combine it into one string for each row to pass to the tokenizer. Note: above when we were looking at just one column 'Position_Extra', we automatically had one string per row.
# Now, we will create a bag of words for each row by joining the strings.
#
# We write a function for that.

# %%
LABELS
# Out:
# ['Function',
#  'Use',
#  'Sharing',
#  'Reporting',
#  'Student_Type',
#  'Position_Type',
#  'Object_Type',
#  'Pre_K',
#  'Operating_Status']

# %%
df_train.columns.tolist()
# Out:
# ['Function',
#  'Use',
#  'Sharing',
#  'Reporting',
#  'Student_Type',
#  'Position_Type',
#  'Object_Type',
#  'Pre_K',
#  'Operating_Status',
#  'Object_Description',
#  'Text_2',
#  'SubFund_Description',
#  'Job_Title_Description',
#  'Text_3',
#  'Text_4',
#  'Sub_Object_Description',
#  'Location_Description',
#  'FTE',
#  'Function_Description',
#  'Facility_or_Department',
#  'Position_Extra',
#  'Total',
#  'Program_Description',
#  'Fund_Description',
#  'Text_1']

# %%
to_drop = NUMERIC_COLUMNS + LABELS

# %%
set(to_drop)
# Out:
# {'FTE',
#  'Function',
#  'Object_Type',
#  'Operating_Status',
#  'Position_Type',
#  'Pre_K',
#  'Reporting',
#  'Sharing',
#  'Student_Type',
#  'Total',
#  'Use'}

# %%
set(to_drop) & set(df_train.columns.tolist())
# Out:
# {'FTE',
#  'Function',
#  'Object_Type',
#  'Operating_Status',
#  'Position_Type',
#  'Pre_K',
#  'Reporting',
#  'Sharing',
#  'Student_Type',
#  'Total',
#  'Use'}

# %%
def combine_text_columns(df, to_drop = NUMERIC_COLUMNS + LABELS):
    """converts all text in each row of data_frame df to a single vector"""
    
    #Drop non-text columns that are in df
    to_drop = set(to_drop) & set(df.columns.tolist())
    
    text_data = df.drop(to_drop, axis = 1)
    
    # Replace nans with blanks
    text_data.fillna('', inplace = True)
    
    # Join all text items in a row that have a space in between
    
    return text_data.apply(lambda x: ' '.join(x), axis = 1)

# %% [markdown]
# Now you will use combine_text_columns() to convert all training text data in your DataFrame to a single vector that can be passed to the vectorizer object and made into a bag-of-words using the .fit_transform() method.
#
# We will use two ways of tokenizing. One using any non-whitespace characters as a token and other using only alphanumeric characters as token.

# %%
# Create the basic token pattern
TOKENS_BASIC = '\\S+(?=\\s+)'

# Create the alphanumeric token pattern
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)'

# %%
vec_basic = CountVectorizer(token_pattern=TOKENS_BASIC)
vec_alphanumeric = CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC)

# %%
text_vector = combine_text_columns(df_train, to_drop = NUMERIC_COLUMNS + LABELS)

# %%
type(text_vector)
# Out:
# pandas.core.series.Series

# %%
text_vector.head()
# Out:
# 134338       Teacher-Elementary        KINDERGARTEN  KIN...
# 206341    CONTRACTOR SERVICES BOND EXPENDITURES BUILDING...
# 326408    Personal Services - Teachers   TCHER 2ND GRADE...
# 364634    EMPLOYEE BENEFITS TEACHER SUBS GENERAL FUND Te...
# 47683     TEACHER COVERAGE FOR TEACHER TEACHER SUBS GENE...
# dtype: object

# %%
df_train.shape
# Out:
# (400277, 25)

# %%
vec_basic.fit_transform(text_vector)
vec_alphanumeric.fit_transform(text_vector)
# Out:
# <400277x3284 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5660399 stored elements in Compressed Sparse Row format>

# %%
vec_basic.get_feature_names()
# Out:
# ['"(year',
#  '"building',
#  '"guidance,',
#  '"human',
#  '"maintenance,',
#  '"multilingual',
#  '"performing',
#  '"software,',
#  '"technology',
#  '"title',
#  '%',
#  '&',
#  '&materials',
#  '&program',
#  '&wildlife',
#  '(',
#  '(4-5)',
#  '(6-8)',
#  '(720)',
#  '(9-',
#  '(9-12)',
#  '(admin',
#  '(afterschool)',
#  '(appl',
#  '(arra)',
#  '(athletic',
#  '(attendance)',
#  '(aut/md)',
#  '(autsm)',
#  '(avid)',
#  '(bilingual)',
#  '(blank)',
#  '(boys)',
#  '(byot)',
#  '(career',
#  '(cbla)',
#  '(cc)',
#  '(cd)',
#  '(cdc-a',
#  '(cdc-a)',
#  '(cdc-a/elem)',
#  '(cdc-a/high)',
#  '(cdc-a/mid)',
#  '(cdc-a/special)',
#  '(cdc-elem)',
#  '(cdc-middle)',
#  '(cdc-secondary)',
#  '(cdc/elem)',
#  '(cdc/high)',
#  '(cdc/mid)',
#  '(cera)',
#  '(cert)',
#  '(child',
#  '(clk&rtrs',
#  '(computer',
#  '(constrct)',
#  '(core)',
#  '(def',
#  '(ed)',
#  '(eg',
#  '(eg)',
#  '(el',
#  '(el)',
#  '(elem',
#  '(elem)',
#  '(eng',
#  '(english)',
#  '(esol)',
#  '(et)',
#  '(ett)',
#  '(excl',
#  '(expenditures',
#  '(external)',
#  '(fam/comm)',
#  '(feb-jun',
#  '(fed',
#  '(fee)',
#  '(fefp',
#  '(gardener)',
#  '(gift)',
#  '(girls)',
#  '(gr',
#  '(grade',
#  '(grades',
#  '(head)',
#  '(headstart)',
#  '(hh)',
#  '(high)',
#  '(host)',
#  '(hs)',
#  '(ii)',
#  '(impact)',
#  '(including',
#  '(interim)',
#  '(iss/high)',
#  '(iss/mid)',
#  '(itemga)',
#  '(job',
#  '(jul-aug',
#  '(k-12)',
#  '(language',
#  '(librarian)',
#  '(licensed',
#  '(lottery)',
#  '(magnet-elem)',
#  '(magnet/elem)',
#  '(maint.',
#  '(md)',
#  '(me)',
#  '(mf)',
#  '(mid)',
#  '(middle',
#  '(middle)',
#  '(no',
#  '(non-local)',
#  '(not',
#  '(office',
#  '(oh)',
#  '(oil)',
#  '(one-on-one)',
#  '(only',
#  '(ose)',
#  '(ot)',
#  '(other',
#  '(participatory',
#  '(perishable',
#  '(phy',
#  '(pool',
#  '(pool)',
#  '(position',
#  '(prevent',
#  '(pt)',
#  '(recycling)',
#  '(rent,',
#  '(resource/elem)',
#  '(resource/high)',
#  '(resource/mid)',
#  '(satellite/elem)',
#  '(satellite/high)',
#  '(satellite/mid)',
#  '(satellite/special)',
#  '(scc)tech',
#  '(school',
#  '(school)',
#  '(sec)',
#  '(secondary)',
#  '(security)',
#  '(slp)',
#  '(sp.ed.)',
#  '(spec',
#  '(speced',
#  '(special',
#  '(special)',
#  '(state',
#  '(summ',
#  '(summer',
#  '(summer)',
#  '(supplemented)',
#  '(tanf)',
#  '(tap)',
#  '(tif)',
#  '(trans)',
#  '(vi)',
#  '(vis)',
#  '(was',
#  '(zz)',
#  ')',
#  '*',
#  '*******suspense*******',
#  '+',
#  ',',
#  '-',
#  '--',
#  '-2nd',
#  '-aba',
#  '-academic',
#  '-accelerated',
#  '-arra',
#  '-beyond',
#  '-ceo',
#  '-crisis',
#  '-emergency',
#  '-ends',
#  '-fam',
#  '-gender',
#  '-host',
#  '-humanware',
#  '-non-instruction',
#  '-orl',
#  '-pre-k',
#  '-rsb',
#  '-sch',
#  '-software',
#  '-strategic',
#  '-yr',
#  '/',
#  '/fte',
#  '/or',
#  '1st',
#  '2nd',
#  '3rd',
#  '4th',
#  '5/6',
#  '56',
#  '5th',
#  '6,7,8',
#  '6-8',
#  '6-8)',
#  '6-8,',
#  '6th',
#  '7-12',
#  '84.00a',
#  '9-12',
#  '9th',
#  '>',
#  '@',
#  'a',
#  'a,',
#  'a-teacher',
#  'a:',
#  'ab',
#  'aba',
#  'abatement',
#  'absence',
#  'ac',
#  'acad',
#  'academic',
#  'academic)',
#  'academically',
#  'academy',
#  'acadmey',
#  'accelerated',
#  'access',
#  'access(constrct',
#  'accessories',
#  'accident',
#  'accnts',
#  'accompanists',
#  'accoun',
#  'account',
#  'account.',
#  'accountability',
#  'accountability,',
#  'accountability-research-eval',
#  'accountant',
#  'accountant,',
#  'accountants',
#  'accounting',
#  'accounts',
#  'accounts-activity',
#  'accounts-governmental',
#  'acct',
#  'acct.',
#  'acctblty',
#  'achiev',
#  'achieve',
#  'achievment',
#  'achv',
#  'acq',
#  'acquis',
#  'acquisition',
#  'acquisition,',
#  'acquisition-current',
#  'acquisitions',
#  'act',
#  'act)',
#  'acte',
#  'acting',
#  'action',
#  'active',
#  'activi',
#  'activiti',
#  'activities',
#  'activity',
#  'activity)',
#  'activties',
#  'actually',
#  'ad',
#  'ada',
#  'adapted',
#  'adaptive',
#  "add'l",
#  'addit',
#  'addition',
#  'additional',
#  'additional/extra',
#  'addl',
#  'adie',
#  'aditional',
#  'adjustme',
#  'adjustment',
#  'adjustments',
#  'adl',
#  'adm',
#  'adm/prod.leader',
#  'adm/prof',
#  'admin',
#  'admin.',
#  'admin.dept.',
#  'adminis',
#  'administ.',
#  'administrat',
#  'administration',
#  'administration"',
#  'administration*',
#  'administrative',
#  'administrative/supervisors*',
#  'administrator',
#  'administrator,',
#  'administrators',
#  'adminsitrative',
#  'adminstrative',
#  'adminstriative',
#  'admissions',
#  'admn',
#  'admn.',
#  'adopt',
#  'adopted',
#  'adult',
#  'adult/continuing',
#  'adults',
#  'advanc',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advances-out',
#  'advaned',
#  'advantage',
#  'advertisements',
#  'advertising',
#  'advisor',
#  'advisor,',
#  'advncmnt',
#  'advocate',
#  'ae',
#  'aefla',
#  'aetna',
#  'affair',
#  'affairs',
#  'aft',
#  'after',
#  'afterschool',
#  'against',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'agreement',
#  'agreements',
#  'agricultural',
#  'agriculture',
#  'agriculture/envrmntl',
#  'agriscience',
#  'aha',
#  'aid',
#  'aid,',
#  'aide',
#  'aide(ded)',
#  'aide,',
#  'aide,60',
#  'aide,60hrs',
#  'aide,70',
#  'aide,70hrs',
#  'aide,70hrs.',
#  'aide,70hs',
#  'aide,80',
#  'aide,80hrs.',
#  'aide,80hs',
#  'aide,bilingua',
#  'aide,computer',
#  'aide,ded,70hr',
#  'aide,headstar',
#  'aide,headstart',
#  'aide,library',
#  'aide,pre-k',
#  'aide,regular',
#  'aide,spec.ed',
#  'aide,sped',
#  'aide,sped,70h',
#  'aide,wae',
#  'aided',
#  'aides',
#  'aides,',
#  'aids',
#  'aids-lunch',
#  'air',
#  'aircraft',
#  'alao',
#  'alarm',
#  'alcolhol',
#  'aligning',
#  'all',
#  'alliance',
#  'alliance-swap',
#  'alloc',
#  'allocation',
#  'allocation-hst',
#  'allocations',
#  'allotment',
#  'allowance',
#  'allowances',
#  'allstate',
#  'alpha',
#  'alrm',
#  'alrms,intrcom-host',
#  'alt',
#  'alt/remodeling',
#  'alter',
#  'alternative',
#  'alumni',
#  'am',
#  'ambassador',
#  'amd-fs',
#  'amendment',
#  'amer.old',
#  'amer/trw',
#  'america',
#  'american',
#  'americorp',
#  'americorps',
#  'ameritech',
#  'an',
#  'ana',
#  'analysis',
#  'analyst',
#  'analyst,',
#  'analyst-',
#  'ancora',
#  'and',
#  'anlayst',
#  'anlyt',
#  'annex',
#  'annual',
#  'annuity',
#  'anonymous',
#  'another',
#  'answer',
#  'anticipated',
#  'any',
#  'aob',
#  'ap',
#  'ap,',
#  'app',
#  'app/non-instru',
#  'appeals',
#  'appl',
#  'apple',
#  'appliance',
#  'application',
#  'applications',
#  'appraisal',
#  'apprentice',
#  'apprenticeship',
#  'apprenticeships',
#  'approp',
#  'appropriation',
#  'approval',
#  'apps',
#  'aquatic',
#  'arbitrage',
#  'arch',
#  'archaelogical',
#  'architect',
#  'architectural&engineering',
#  'architecture',
#  'ard',
#  'area',
#  'army',
#  'around',
#  'arra',
#  'arra(stars)',
#  'arra-homeless',
#  'arra-i-a',
#  'arra-nat',
#  'arra-nonpublic',
#  'arra-salary',
#  'arra-sw',
#  'arra-t-i',
#  'arra-title',
#  'art',
#  'art-elem',
#  'art-high',
#  'art-middle',
#  'articulated',
#  'artist',
#  'arts',
#  'arts,other',
#  'arts-high',
#  'arts-middle',
#  'arts/culture',
#  'arts/tech',
#  'arts/technology',
#  'asbestos',
#  'asd',
#  'asfepa-',
#  'asia',
#  'aside',
#  'ass.',
#  'assembler',
#  'assesment',
#  'assess',
#  'assess.',
#  'assessment',
#  'assessments',
#  'asset',
#  'assets',
#  'assets,',
#  'assgmt',
#  'assgn',
#  'assgnmt',
#  'assi',
#  'assign',
#  'assign,',
#  'assign-sh',
#  'assign/attendance/re',
#  'assignment',
#  'assignments',
#  'assis',
#  'assist',
#  'assist(cdc/special',
#  'assist(satellite/special)',
#  'assista',
#  'assistan',
#  'assistance',
#  'assistane',
#  'assistant',
#  'assistant,',
#  'assistant-elem',
#  'assistant-ell',
#  'assistant-esol',
#  'assistant-high',
#  'assistant-pk',
#  'assistant-rotc',
#  'assistant-title',
#  'assistants',
#  'assistive',
#  'assitant',
#  'assmt',
#  'assmt/tst',
#  'assn',
#  'assoc',
#  'assoc,',
#  'assoc.',
#  'associate',
#  'associate,project',
#  'associated',
#  'asst',
#  'asst,',
#  'asst-boys',
#  'asst-girls',
#  'asst-sp',
#  'asst.',
#  'asst/clerk',
#  'asst/exec',
#  'asst/records',
#  'assur',
#  'assurance',
#  'asthma',
#  'at',
#  'ath',
#  'athletic',
#  'athletic/academic',
#  'athletics',
#  'athletics/sports',
#  'atrt',
#  'atsp',
#  'attendance',
#  'attendant',
#  'attendence',
#  'attn',
#  'attorney',
#  'attorneys',
#  'attorneys,legal',
#  'atwll',
#  'audio',
#  'audio/visual',
#  'audiologist',
#  'audiology',
#  'audiovisual',
#  'audit',
#  'auditing',
#  'auditor',
#  'auditor/accountant',
#  'auditory',
#  'august',
#  'aut/md',
#  'autism',
#  'autistic',
#  'auto',
#  'auto:hs',
#  'automation',
#  'automotive',
#  'autonamy',
#  'autonomous',
#  'aux',
#  'auxiliary',
#  'av',
#  'av/archivist',
#  'av/pc',
#  'avenue',
#  'avg',
#  'aviation',
#  'avid',
#  'award',
#  'awards',
#  'awards/prizes',
#  'ayp',
#  'b',
#  'b-',
#  'b-main',
#  'b-team',
#  'b-team-bo',
#  'b-team-gi',
#  'b:',
#  'ba',
#  'baccalaur',
#  'baccalaurate',
#  'bachelor',
#  'back',
#  'background',
#  'backpack',
#  'baker',
#  'bakery',
#  'band',
#  'bank',
#  'banking',
#  'banquets',
#  'barbering',
#  'barrier',
#  'base/sftball',
#  'baseball',
#  'based',
#  'basic',
#  'basis',
#  'basketball',
#  'bbb',
#  'bckflw',
#  'bd',
#  'bdgt',
#  'be',
#  'beat',
#  'beginning',
#  'behav',
#  'behav.',
#  'behavior',
#  'behavioral',
#  'behaviorial/interv',
#  'behavorial',
#  'believers',
#  'bell',
#  'benchmark',
#  'benefit',
#  'benefits',
#  'benefits)',
#  'benefits,',
#  'benefits/wc',
#  'best',
#  'bga',
#  'bga-gesp',
#  'bgt',
#  'bi',
#  'bible',
#  'bicycle',
#  'bil',
#  'biling',
#  'bilingual',
#  'bilingual,',
#  'bilingual/multicultural',
#  'bilinguial',
#  'billing',
#  'bilng',
#  'bilngl',
#  'binding',
#  'binding,',
#  'binligual',
#  'bio/chem',
#  'biological',
#  'biology',
#  'bird',
#  'birth',
#  'birth/kind',
#  'bks',
#  'bks-hst',
#  'black',
#  'bldg',
#  'bldg.&',
#  'bldgs',
#  'blind',
#  'blngl',
#  'block',
#  'bnc-supervisor',
#  'board',
#  'body',
#  'body-sound',
#  'boiler',
#  'boiler/combustion',
#  'boilermaker',
#  'boilers',
#  'bolton',
#  'bond',
#  'bonding',
#  'bonds',
#  'bonus',
#  'bonuses',
#  'book',
#  'bookkeeper',
#  'bookkeepers',
#  'books',
#  'books,',
#  'boost',
#  'boot',
#  'bottled',
#  'bowl-curriculum',
#  'boys',
#  'bp',
#  'braille',
#  'brandmuscle-adobe',
#  'brd',
#  'breaker',
#  'breakfast',
#  'brick',
#  'bricklayer',
#  'bricks',
#  'bridge',
#  'bright',
#  'brkfast',
#  'broad',
#  'broadcast',
#  'broadcasting',
#  'broken',
#  'brothers',
#  'bsi',
#  'budg',
#  'budget',
#  'budget/finance',
#  'budgetary',
#  'budgeting',
#  'budgets',
#  'budgets/schools',
#  'buhrer',
#  'building',
#  'building/property',
#  'buildings',
#  'buisness',
#  'bulk',
#  'bump',
#  'bunch',
#  'bureau',
#  'bus',
#  'bus.&',
#  'bus/lbr/univ/cult',
#  'buses',
#  'busine',
#  'business',
#  'business,',
#  'business/admin',
#  'buy',
#  'buyer',
#  'by',
#  'c',
#  'c&i',
#  'c.o.p.',
#  'c/o-early',
#  'c/o-summer',
#  'cabinet',
#  'cabinetmaker',
#  'cable',
#  'cad',
#  'cadre',
#  'cafe',
#  'cafeteria',
#  'camera',
#  'camp',
#  'camp-summer',
#  'campbell',
#  'camps',
#  'campus',
#  'candies',
#  'candle',
#  'candy',
#  'cao',
#  'cap',
#  'capacity',
#  'cape-undesignated',
#  'capital',
#  'capitalized',
#  'captain',
#  'car-tech',
#  'card',
#  'cards',
#  'care',
#  'careeer',
#  'career',
#  'career/technology',
#  'caretaker',
#  'carl',
#  'carpenter',
#  'carpentry',
#  'carpentry/cabinet',
#  'carpet',
#  'carreer',
#  'carrier',
#  'carryforward',
#  'carryover',
#  'carryover-summer',
#  'case',
#  'cash',
#  'cashier',
#  'catalyst',
#  'category',
#  'catholic',
#  'cc/oh',
#  'cclc',
#  'ccoach',
#  'cdb',
#  'cde/qwest',
#  'ce',
#  'cec',
#  'cec-autobody',
#  'cec-automechanics',
#  'cec-child',
#  'cec-restaurant',
#  'ceis',
#  'cela',
#  'celeb',
#  'cen',
#  'cent',
#  'center',
#  'center-rec',
#  'centers',
#  'central',
#  'century',
#  'century/',
#  'ceo',
#  'cert',
#  'cert.',
#  'certificated',
#  'certification',
#  'certifications-life',
#  'certified',
#  'certifiedaddl',
#  'cf',
#  'cfda',
#  'cfo',
#  'ch',
#  'cha',
#  'chai',
#  'chair',
#  'chair.',
#  'challenge',
#  'challenge/fy',
#  'champions',
#  'chance',
#  'chancellor',
#  'chanclr',
#  'change',
#  'chapter',
#  'character',
#  'charge',
#  'charge/reimbur',
#  'charges',
#  'charitable',
#  'charities',
#  'charity',
#  'charity-',
#  'charity-imp',
#  'charter',
#  'charters',
#  'charting',
#  'chdrn',
#  'che',
#  'cheerlea',
#  'cheerleader',
#  'cheerleaders',
#  'cheerleading',
#  'chef',
#  'chemistry',
#  'chief',
#  'chief,',
#  'chief,hmn',
#  'chief,organizational',
#  'chief-facilities/operations',
#  'child',
#  'childcare',
#  'childhd',
#  'childhood',
#  'childn/youth',
#  'children',
#  "children's",
#  'children/targeted',
#  'chiller/absorber',
#  'chinese',
#  'chllnge',
#  'choice',
#  'choice-county',
#  'choir',
#  'choir,',
#  'choral',
#  'chorus',
#  'chosen',
#  'christian',
#  'chrtr',
#  'church',
#  'cie',
#  'cisco',
#  'city',
#  'city-rsb',
#  'city-rsb-fy',
#  'city:',
#  'civics',
#  'claiming',
#  'claims',
#  'class',
#  'class-size',
#  'classified',
#  'classroom',
#  'classroon',
#  'clean',
#  'cleaner',
#  'cleaners',
#  'cleaning',
#  'cleaning/chemical',
#  'clerical',
#  'clerical,',
#  'clerical,area',
#  'clerical,district',
#  'clerical,warehouse/receiving',
#  'clerical-summer',
#  'clerical/bookkeeper',
#  'clerical/tchr',
#  'clerk',
#  'clerk,',
#  'clerk,data',
#  'clerk,library',
#  'clerk,non-typing',
#  'clerk,office',
#  'clerk,typing',
#  'clerk/data',
#  'client',
#  'climate',
#  'climbing',
#  'clinic',
#  'clinic-math',
#  'clinical',
#  'clk',
#  'clk/fire',
#  'closed',
#  'closeures',
#  'closing',
#  'clothing',
#  'clout',
#  'club',
#  'cluster',
#  'cms',
#  'cmsd',
#  'cnflct',
#  'cnslg',
#  'cntr',
#  'cntrl',
#  'cntry',
#  'co',
#  'co-curricular',
#  'co-dispatcher',
#  'co-praxis',
#  'co-tchr',
#  'coa',
#  'coac',
#  'coach',
#  'coach,',
#  'coach/specialist',
#  'coaches',
#  'coaching',
#  'coalit',
#  'coalition',
#  'coappp',
#  'coatings',
#  'cocurricular',
#  'cocurriculum/extra-curricular',
#  'code',
#  'cogat-gt',
#  'cohart',
#  'cohort',
#  'coll',
#  'collabo',
#  'collabor',
#  'collaboratives',
#  'collection',
#  'collections',
#  'college',
#  'college/schools',
#  'collegiate',
#  'colleyball',
#  'collision',
#  'colorado',
#  'com',
#  'combination',
#  'comes',
#  ...]

# %%
vec_alphanumeric.get_feature_names()
# Out:
# ['00a',
#  '12',
#  '1st',
#  '2nd',
#  '3rd',
#  '4th',
#  '5',
#  '56',
#  '5th',
#  '6',
#  '60',
#  '60hrs',
#  '6th',
#  '70',
#  '70h',
#  '70hr',
#  '70hrs',
#  '70hs',
#  '8',
#  '80',
#  '80hs',
#  '9th',
#  'a',
#  'aaps',
#  'ab',
#  'aba',
#  'abatement',
#  'absence',
#  'absorber',
#  'ac',
#  'acad',
#  'academ',
#  'academic',
#  'academically',
#  'academy',
#  'acadmey',
#  'accelerated',
#  'access',
#  'accessories',
#  'accident',
#  'accnts',
#  'accompanists',
#  'accoun',
#  'account',
#  'accountability',
#  'accountant',
#  'accountants',
#  'accounting',
#  'accounts',
#  'acct',
#  'acctblty',
#  'achiev',
#  'achieve',
#  'achievment',
#  'achv',
#  'acq',
#  'acquis',
#  'acquisition',
#  'acquisitions',
#  'act',
#  'acte',
#  'acting',
#  'action',
#  'active',
#  'activi',
#  'activiti',
#  'activities',
#  'activity',
#  'activties',
#  'actually',
#  'actuary',
#  'ad',
#  'ada',
#  'adapted',
#  'adaptive',
#  'addit',
#  'addition',
#  'additional',
#  'addl',
#  'addtn',
#  'adie',
#  'aditional',
#  'adjustme',
#  'adjustment',
#  'adjustments',
#  'adl',
#  'adm',
#  'admin',
#  'adminis',
#  'administrat',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adminsitrative',
#  'adminstrative',
#  'adminstriative',
#  'admissions',
#  'admn',
#  'adobe',
#  'adopt',
#  'adopted',
#  'adult',
#  'adults',
#  'advanc',
#  'advance',
#  'advanced',
#  'advancement',
#  'advances',
#  'advaned',
#  'advantage',
#  'advertisements',
#  'advertising',
#  'advisor',
#  'advncmnt',
#  'advocate',
#  'ae',
#  'aefla',
#  'aetna',
#  'affair',
#  'affairs',
#  'aft',
#  'after',
#  'afterschool',
#  'against',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'agreement',
#  'agreements',
#  'agricultural',
#  'agriculture',
#  'agriscience',
#  'aha',
#  'aid',
#  'aide',
#  'aided',
#  'aides',
#  'aids',
#  'air',
#  'aircraft',
#  'alao',
#  'alarm',
#  'alcolhol',
#  'aligning',
#  'all',
#  'allcity',
#  'alliance',
#  'alloc',
#  'allocation',
#  'allocations',
#  'allotment',
#  'allowance',
#  'allowances',
#  'allstate',
#  'alpha',
#  'alrm',
#  'alt',
#  'alter',
#  'alternative',
#  'alumni',
#  'am',
#  'ambassador',
#  'amendment',
#  'america',
#  'american',
#  'americorp',
#  'americorps',
#  'ameritech',
#  'an',
#  'ana',
#  'analysis',
#  'analyst',
#  'ancora',
#  'and',
#  'animal',
#  'anlayst',
#  'anlyt',
#  'annex',
#  'annual',
#  'annuity',
#  'anonymous',
#  'another',
#  'anschut',
#  'answer',
#  'anticipated',
#  'any',
#  'aob',
#  'ap',
#  'app',
#  'appeals',
#  'appl',
#  'apple',
#  'appliance',
#  'application',
#  'applications',
#  'appraisal',
#  'apprec',
#  'apprentice',
#  'apprenticeship',
#  'apprenticeships',
#  'approp',
#  'appropriation',
#  'approval',
#  'apps',
#  'aquatic',
#  'arbitrage',
#  'arboreal',
#  'arch',
#  'archaelogical',
#  'architect',
#  'architecture',
#  'archivist',
#  'ard',
#  'area',
#  'army',
#  'around',
#  'arra',
#  'art',
#  'articulated',
#  'artist',
#  'arts',
#  'asbestos',
#  'asd',
#  'asia',
#  'aside',
#  'assembler',
#  'assesment',
#  'assess',
#  'assessment',
#  'assessments',
#  'asset',
#  'assets',
#  'assgmt',
#  'assgn',
#  'assgnmt',
#  'assi',
#  'assign',
#  'assignment',
#  'assignments',
#  'assis',
#  'assist',
#  'assista',
#  'assistan',
#  'assistance',
#  'assistane',
#  'assistant',
#  'assistants',
#  'assistive',
#  'assitant',
#  'assmt',
#  'assn',
#  'assoc',
#  'associate',
#  'associated',
#  'asst',
#  'assur',
#  'assurance',
#  'asthma',
#  'at',
#  'ath',
#  'athl',
#  'athletic',
#  'athletics',
#  'atrt',
#  'atsp',
#  'attendance',
#  'attendant',
#  'attendence',
#  'attn',
#  'attorney',
#  'attorneys',
#  'atwll',
#  'audio',
#  'audiologi',
#  'audiologist',
#  'audiology',
#  'audiovisual',
#  'audit',
#  'auditing',
#  'auditor',
#  'auditory',
#  'aug',
#  'august',
#  'autism',
#  'autistic',
#  'auto',
#  'autobody',
#  'automation',
#  'automechanics',
#  'automotive',
#  'autonamy',
#  'autonomous',
#  'aux',
#  'auxiliary',
#  'av',
#  'avenue',
#  'avg',
#  'aviation',
#  'avid',
#  'award',
#  'awards',
#  'ayp',
#  'b',
#  'ba',
#  'baccalaur',
#  'baccalaurate',
#  'bachelor',
#  'back',
#  'background',
#  'backpack',
#  'baker',
#  'bakery',
#  'band',
#  'bank',
#  'banking',
#  'banquets',
#  'barbering',
#  'barrier',
#  'baseball',
#  'based',
#  'basic',
#  'basis',
#  'basketball',
#  'bbb',
#  'bcbs',
#  'bckflw',
#  'bd',
#  'bdgt',
#  'be',
#  'beat',
#  'beginning',
#  'behalf',
#  'behav',
#  'behavior',
#  'behavioral',
#  'behavorial',
#  'believers',
#  'bell',
#  'benchmark',
#  'benef',
#  'benefit',
#  'benefits',
#  'best',
#  'beyond',
#  'bga',
#  'bgt',
#  'bi',
#  'bible',
#  'bicycle',
#  'bil',
#  'biling',
#  'bilingua',
#  'bilingual',
#  'bilinguial',
#  'billing',
#  'bilng',
#  'bilngl',
#  'binding',
#  'binligual',
#  'biological',
#  'biology',
#  'bird',
#  'birth',
#  'bks',
#  'black',
#  'bldg',
#  'bldgs',
#  'blind',
#  'blk',
#  'blngl',
#  'block',
#  'bo',
#  'board',
#  'body',
#  'boiler',
#  'boilermaker',
#  'boilers',
#  'bolton',
#  'bond',
#  'bonding',
#  'bonds',
#  'bonus',
#  'bonuses',
#  'book',
#  'bookkeeper',
#  'bookkeepers',
#  'books',
#  'boost',
#  'boot',
#  'bottled',
#  'boy',
#  'boys',
#  'bp',
#  'braille',
#  'brd',
#  'breaker',
#  'breakfast',
#  'brick',
#  'bricklayer',
#  'bricks',
#  'bridge',
#  'bright',
#  'brkfast',
#  'broad',
#  'broadcast',
#  'broadcasting',
#  'broken',
#  'brothers',
#  'bs',
#  'bsi',
#  'budg',
#  'budget',
#  'budgetary',
#  'budgeting',
#  'budgets',
#  'buhrer',
#  'building',
#  'buildings',
#  'buisness',
#  'bulk',
#  'bump',
#  'bunch',
#  'bureau',
#  'bus',
#  'buses',
#  'busine',
#  'business',
#  'buy',
#  'buyer',
#  'by',
#  'c',
#  'cabinet',
#  'cabinetmaker',
#  'cable',
#  'cad',
#  'cadd',
#  'cadre',
#  'cafe',
#  'cafeteria',
#  'camera',
#  'camp',
#  'campbell',
#  'camps',
#  'campus',
#  'candies',
#  'candle',
#  'candy',
#  'cao',
#  'cap',
#  'capacity',
#  'capital',
#  'capitalized',
#  'captain',
#  'card',
#  'cards',
#  'care',
#  'careeer',
#  'career',
#  'caregiver',
#  'caretaker',
#  'carl',
#  'carnegie',
#  'carpenter',
#  'carpentry',
#  'carpet',
#  'carreer',
#  'carrier',
#  'carryforward',
#  'carryover',
#  'case',
#  'cash',
#  'cashier',
#  'catalyst',
#  'category',
#  'catholic',
#  'cclc',
#  'ccoach',
#  'cdb',
#  'cdc',
#  'ce',
#  'cec',
#  'ceis',
#  'cela',
#  'celeb',
#  'cen',
#  'cent',
#  'center',
#  'centers',
#  'central',
#  'century',
#  'ceo',
#  'ceramic',
#  'cert',
#  'certificated',
#  'certification',
#  'certified',
#  'certifiedaddl',
#  'cf',
#  'cfda',
#  'cfo',
#  'ch',
#  'cha',
#  'chai',
#  'chair',
#  'challenge',
#  'champions',
#  'chance',
#  'chancellor',
#  'chanclr',
#  'change',
#  'chapter',
#  'char',
#  'character',
#  'charge',
#  'charges',
#  'charitable',
#  'charities',
#  'charity',
#  'charter',
#  'charters',
#  'charting',
#  'chdrn',
#  'che',
#  'cheerlea',
#  'cheerleader',
#  'cheerleaders',
#  'cheerleading',
#  'chef',
#  'chem',
#  'chemical',
#  'chemistry',
#  'chief',
#  'child',
#  'childcare',
#  'childhd',
#  'childhood',
#  'children',
#  'chinese',
#  'chllnge',
#  'choice',
#  'choir',
#  'choral',
#  'chorus',
#  'chosen',
#  'christian',
#  'chrtr',
#  'church',
#  'cie',
#  'cisco',
#  'city',
#  'civics',
#  'claiming',
#  'claims',
#  'class',
#  'classified',
#  'classroom',
#  'classroon',
#  'clean',
#  'cleaner',
#  'cleaners',
#  'cleaning',
#  'clerical',
#  'clerk',
#  'client',
#  'climate',
#  'climbing',
#  'clinic',
#  'clinical',
#  'clk',
#  'clos',
#  'closed',
#  'closeures',
#  'closing',
#  'clothing',
#  'clout',
#  'cls',
#  'club',
#  'cluster',
#  'cms',
#  'cmsd',
#  'cnflct',
#  'cnfrn',
#  'cnslg',
#  'cntr',
#  'cntrl',
#  'cntry',
#  'co',
#  'coa',
#  'coac',
#  'coach',
#  'coaches',
#  'coaching',
#  'coalit',
#  'coalition',
#  'coappp',
#  'coatings',
#  'cocurricular',
#  'code',
#  'cohart',
#  'cohort',
#  'coll',
#  'collabo',
#  'collabor',
#  'collaboratives',
#  'collection',
#  'collections',
#  'college',
#  'collegiate',
#  'colleyball',
#  'collision',
#  'colorado',
#  'com',
#  'combination',
#  'combustion',
#  'comes',
#  'comm',
#  'command',
#  'commerc',
#  'commission',
#  'commissions',
#  'commodities',
#  'commodity',
#  'common',
#  'commty',
#  'communicatio',
#  'communication',
#  'communications',
#  'communities',
#  'community',
#  'comp',
#  'compass',
#  'compen',
#  'compensation',
#  'compensatory',
#  'competency',
#  'competition',
#  'competitive',
#  'compl',
#  'completion',
#  'complex',
#  'compliance',
#  'composition',
#  'comprehensive',
#  'comptr',
#  'comptrolle',
#  'compute',
#  'computer',
#  'computers',
#  'computing',
#  'concepts',
#  'concession',
#  'concessions',
#  'concussion',
#  'condiments',
#  'condition',
#  'conf',
#  'confer',
#  'conference',
#  'conflict',
#  'cong',
#  'connect',
#  'connections',
#  'conservation',
#  'conslt',
#  'consolidated',
#  'consolidation',
#  'consolidations',
#  'consortium',
#  'const',
#  'constituency',
#  'constr',
#  'constrct',
#  'construction',
#  'constuction',
#  'consul',
#  'consultant',
#  'consultants',
#  'consumer',
#  'cont',
#  'contact',
#  'containd',
#  'contained',
#  'contemporary',
#  'content',
#  'contingencies',
#  'contingency',
#  'continuing',
#  'contr',
#  'contra',
#  'contract',
#  'contracted',
#  'contracting',
#  'contractor',
#  'contractors',
#  'contracts',
#  'contractual',
#  'contributing',
#  'contribution',
#  'contro',
#  'control',
#  'controller',
#  'controls',
#  'conversion',
#  'coo',
#  'cook',
#  'cooperating',
#  'coor',
#  'coord',
#  'coordinated',
#  'coordination',
#  'coordinator',
#  'cop',
#  'copayment',
#  'copier',
#  'copiers',
#  'cops',
#  'copy',
#  'copying',
#  'core',
#  'cornerstone',
#  'corp',
#  'corporal',
#  'corps',
#  'correction',
#  'correctionist',
#  'cos',
#  'cosmetology',
#  'cosmotology',
#  'cost',
#  'costs',
#  'costume',
#  'coteaching',
#  'council',
#  'couns',
#  'counsel',
#  'counseling',
#  'counselor',
#  'counselors',
#  'count',
#  'counter',
#  'counterman',
#  'countr',
#  'country',
#  'county',
#  'coupon',
#  'court',
#  'coverage',
#  'covered',
#  'cpa',
#  'craft',
#  'crdt',
#  'create',
#  'creating',
#  'creative',
#  'credit',
#  'crew',
#  'criminal',
#  'crisis',
#  'crit',
#  'critical',
#  'cross',
#  'crossing',
#  'crt',
#  'crystal',
#  'cst',
#  'csx',
#  'ctae',
#  'cte',
#  'cti',
#  'ctl',
#  'cto',
#  'ctr',
#  'ctu',
#  'cty',
#  'culinary',
#  'cult',
#  'culture',
#  'cultures',
#  'curator',
#  'curr',
#  'current',
#  'curricular',
#  'curriculum',
#  'cus',
#  'cusotidan',
#  'cust',
#  'custodain',
#  'custodial',
#  'custodian',
#  'custodians',
#  'customer',
#  'customized',
#  'cutters',
#  'd',
#  'da',
#  'daep',
#  'daily',
#  'damaged',
#  'dance',
#  'data',
#  'database',
#  'datacoord',
#  'day',
#  'days',
#  'dc',
#  'dcta',
#  'deaf',
#  'dean',
#  'debate',
#  'debt',
#  'dec',
#  'decathlon',
#  'decis',
#  'decision',
#  'decrease',
#  'dedicated',
#  'deductible',
#  'deep',
#  'def',
#  'defined',
#  'degreed',
#  'del',
#  'deli',
#  'delinq',
#  'delinquent',
#  'delivery',
#  'dell',
#  'delta',
#  'demnd',
#  'demolition',
#  'dental',
#  'dep',
#  'department',
#  'departments',
#  'depot',
#  'depreciation',
#  'dept',
#  'depty',
#  'deputy',
#  'des',
#  'description',
#  'desgn',
#  'design',
#  'designated',
#  'desk',
#  'desktop',
#  'destination',
#  'destructive',
#  'detective',
#  'determ',
#  'determination',
#  'dev',
#  'develop',
#  'develope',
#  'developer',
#  'development',
#  'developmentally',
#  'develpmnt',
#  'develpmt',
#  'devices',
#  'devp',
#  'dhh',
#  'dhr',
#  'di',
#  'diabetes',
#  'diagnostic',
#  'diagnostician',
#  'diagnosticians',
#  'diags',
#  'diesel',
#  'dietary',
#  'dietician',
#  'diff',
#  'differential',
#  'differentiated',
#  'digital',
#  'dinner',
#  'dipl',
#  'diploma',
#  'diplomas',
#  'dir',
#  'direc',
#  'direct',
#  'direction',
#  'directo',
#  'director',
#  'directory',
#  'directr',
#  'dis',
#  'disabilit',
#  'disabilities',
#  'disability',
#  'disabled',
#  'disadvantaged',
#  'disbursing',
#  'discharged',
#  'disciplinary',
#  'discipline',
#  'discovery',
#  'discretionary',
#  'dislocated',
#  'disord',
#  'disorder',
#  'disorders',
#  'dispatch',
#  'dispatcher',
#  'dispensing',
#  'disposal',
#  'dist',
#  'distance',
#  'distinction',
#  'distinguished',
#  'distributed',
#  'distribution',
#  'district',
#  'districts',
#  'districtwide',
#  'div',
#  'diversified',
#  'diversity',
#  'division',
#  'do',
#  'doctoral',
#  'doctorate',
#  'document',
#  'doe',
#  'dollar',
#  'dollars',
#  'domestic',
#  'donat',
#  'donated',
#  'donation',
#  'donations',
#  'donors',
#  'dop',
#  'dot',
#  'dots',
#  'dr',
#  'drama',
#  'dream',
#  'driver',
#  'drivers',
#  'drnge',
#  'drop',
#  'dropout',
#  'drug',
#  'drum',
#  'ds',
#  'dual',
#  'duck',
#  'dues',
#  'duplicating',
#  'duplicator',
#  'duty',
#  'dvlp',
#  'dvlpmnt',
#  'dyslexia',
#  'e',
#  'each',
#  'early',
#  'earth',
#  'east',
#  'eaton',
#  'ebd',
#  'ec',
#  'ece',
#  'ecea',
#  'econ',
#  'economic',
#  'economics',
#  'ecse',
#  'ed',
#  'edcuational',
#  'editor',
#  'edu',
#  'educ',
#  'educat',
#  'education',
#  'educational',
#  'educatoinal',
#  'educator',
#  'educators',
#  'eett',
#  'eff',
#  'effective',
#  'effectiveness',
#  'eg',
#  'eii',
#  'eis',
#  'el',
#  'ela',
#  'elc',
#  'election',
#  'electr',
#  'electrical',
#  'electrician',
#  ...]

# %%
df_train.iloc[1, :]
# Out:
# Function                                       NO_LABEL
# Use                                            NO_LABEL
# Sharing                                        NO_LABEL
# Reporting                                      NO_LABEL
# Student_Type                                   NO_LABEL
# Position_Type                                  NO_LABEL
# Object_Type                                    NO_LABEL
# Pre_K                                          NO_LABEL
# Operating_Status                          Non-Operating
# Object_Description                  CONTRACTOR SERVICES
# Text_2                                BOND EXPENDITURES
# SubFund_Description                       BUILDING FUND
# Job_Title_Description                           (blank)
# Text_3                                          Regular
# Text_4                                              NaN
# Sub_Object_Description                              NaN
# Location_Description                                NaN
# FTE                                                 NaN
# Function_Description                           RGN  GOB
# Facility_or_Department                              NaN
# Position_Extra                             UNDESIGNATED
# Total                                           3477.86
# Program_Description       BUILDING IMPROVEMENT SERVICES
# Fund_Description                                    NaN
# Text_1                    BUILDING IMPROVEMENT SERVICES
# Name: 206341, dtype: object

# %%
len(vec_basic.get_feature_names())
# Out:
# 4758

# %%
len(vec_alphanumeric.get_feature_names())
# Out:
# 3284

# %% [markdown]
# Tokenizing on alpha-numeric tokens reduces the number of token.

# %% [markdown]
# ### Let's build a pipeline
#
# The Pipeline workflow is a
#
# * Repeatable way to go from raw data to trained model
#
# * Pipieline object takes sequential list of steps
#
# * Output of one step is input to next step
#
# * Each step is a tuple with two elements -- the name which is a string, and an object that implements .fit() and .transform() methods
#
# * Pipeline are a flexible way to represent the workflow. In fact, a step can itself be another pipeline.
#
# The problem here is that the text and numeric data don't work together. For instance, CountVectorizer doesn't know what to do with numeric data and Imputer doesn't know how to imput on text columns.
#
# Solution: buid two different pipelines using FunctionTransformer and put them together using FeatureUnion.

# %%
NUMERIC_COLUMNS + LABELS
# Out:
# ['FTE',
#  'Total',
#  'Function',
#  'Use',
#  'Sharing',
#  'Reporting',
#  'Student_Type',
#  'Position_Type',
#  'Object_Type',
#  'Pre_K',
#  'Operating_Status']

# %%
ALL_COLUMNS = df_train.columns.tolist()

# %%
TEXT_COLUMNS = list(np.setdiff1d(ALL_COLUMNS, NUMERIC_COLUMNS + LABELS))

# %%
TEXT_COLUMNS
# Out:
# ['Facility_or_Department',
#  'Function_Description',
#  'Fund_Description',
#  'Job_Title_Description',
#  'Location_Description',
#  'Object_Description',
#  'Position_Extra',
#  'Program_Description',
#  'SubFund_Description',
#  'Sub_Object_Description',
#  'Text_1',
#  'Text_2',
#  'Text_3',
#  'Text_4']

# %% [markdown]
# Note we need to use the combine_text_columns function because our tokenizer accepts one string.

# %%
get_text_data = FunctionTransformer(combine_text_columns, validate = False)

# %% [markdown]
# FunctionTransformer job is to take a Python function and turn it into an object that a scikit-learn pipeline can understand.
#
# The validate=False tells scikit-learn it doesn't need to check for NaNs or validate the dtypes of the input. We will do that work outselves.

# %%
get_numeric_data = FunctionTransformer(lambda x: x[NUMERIC_COLUMNS], validate = False)

# %%
get_numeric_data
# Out:
# FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprecated',
#           validate=False)

# %%
df_train[TEXT_COLUMNS].head()
# Out:
#        Facility_or_Department     Function_Description  \
# 134338                    NaN                      NaN
# 206341                    NaN                 RGN  GOB
# 326408                    NaN                      NaN
# 364634                    NaN  UNALLOC BUDGETS/SCHOOLS
# 47683                     NaN              NON-PROJECT
#
#               Fund_Description       Job_Title_Description  \
# 134338            General Fund         Teacher-Elementary
# 206341                     NaN                     (blank)
# 326408  General Purpose School             TCHER 2ND GRADE
# 364634                     NaN    Teacher, Short Term Sub
# 47683                      NaN  Teacher, Secondary (High)
#
#        Location_Description            Object_Description  \
# 134338                  NaN                           NaN
# 206341                  NaN           CONTRACTOR SERVICES
# 326408                  NaN  Personal Services - Teachers
# 364634                  NaN             EMPLOYEE BENEFITS
# 47683                   NaN  TEACHER COVERAGE FOR TEACHER
#
#                     Position_Extra             Program_Description  \
# 134338               KINDERGARTEN                     KINDERGARTEN
# 206341                UNDESIGNATED   BUILDING IMPROVEMENT SERVICES
# 326408                     TEACHER           Instruction - Regular
# 364634  PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683   PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
#
#        SubFund_Description Sub_Object_Description  \
# 134338                 NaN                    NaN
# 206341       BUILDING FUND                    NaN
# 326408                 NaN                    NaN
# 364634        GENERAL FUND                    NaN
# 47683         GENERAL FUND                    NaN
#
#                                Text_1             Text_2       Text_3  \
# 134338                            NaN                NaN          NaN
# 206341  BUILDING IMPROVEMENT SERVICES  BOND EXPENDITURES      Regular
# 326408                            NaN                NaN          NaN
# 364634            REGULAR INSTRUCTION       TEACHER SUBS      Regular
# 47683             REGULAR INSTRUCTION       TEACHER SUBS  Alternative
#
#                      Text_4
# 134338                  NaN
# 206341                  NaN
# 326408  Regular Instruction
# 364634                  NaN
# 47683                   NaN

# %%
just_text_data = get_text_data.fit_transform(df_train)

# %%
just_text_data.head()
# Out:
# 134338       Teacher-Elementary        KINDERGARTEN  KIN...
# 206341    CONTRACTOR SERVICES BOND EXPENDITURES BUILDING...
# 326408    Personal Services - Teachers   TCHER 2ND GRADE...
# 364634    EMPLOYEE BENEFITS TEACHER SUBS GENERAL FUND Te...
# 47683     TEACHER COVERAGE FOR TEACHER TEACHER SUBS GENE...
# dtype: object

# %%
just_text_data.shape
# Out:
# (400277,)

# %%
len(TEXT_COLUMNS)
# Out:
# 14

# %%
just_numeric_data = get_numeric_data.fit_transform(df_train)

# %%
just_numeric_data.shape
# Out:
# (400277, 2)

# %% [markdown]
# ### Using FeatureUnion()
#
# We combine the multiple type of feature processing using the FeatureUnion utility for scikit-learn.
#
# Before that we use the multilabel_train_test_split() we defined above on all of the data set.

# %%
X_train, X_test, y_train, y_test = multilabel_train_test_split(df_train[NUMERIC_COLUMNS + TEXT_COLUMNS],
                                                               pd.get_dummies(df_train[LABELS]),
                                                               size=0.2, 
                                                               seed=123)

# %% [markdown]
# ** Create a FeatureUnion with nested pipeline **

# %%
process_and_join_features = FeatureUnion(
                            transformer_list = [
                                ('numeric_features', Pipeline([
                                    ('selector', get_numeric_data),
                                    ('imputer', Imputer())
                                ])), 
                                ('text_features', Pipeline([
                                    ('selector', get_text_data),
                                    ('vectorizer', CountVectorizer())
                                ]))
                            ])

# %%
process_and_join_features_alphanum = FeatureUnion(
                            transformer_list = [
                                ('numeric_features', Pipeline([
                                    ('selector', get_numeric_data),
                                    ('imputer', Imputer())
                                ])), 
                                ('text_features', Pipeline([
                                    ('selector', get_text_data),
                                    ('vectorizer', CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC, ngram_range=(1, 2)))
                                ]))
                            ])

# %%
process_and_join_features_basic = FeatureUnion(
                            transformer_list = [
                                ('numeric_features', Pipeline([
                                    ('selector', get_numeric_data),
                                    ('imputer', Imputer())
                                ])), 
                                ('text_features', Pipeline([
                                    ('selector', get_text_data),
                                    ('vectorizer', CountVectorizer(token_pattern=TOKENS_BASIC))
                                ]))
                            ])

# %%
pl = Pipeline([
    ('union', process_and_join_features),
    ('clf', OneVsRestClassifier(LogisticRegression()))
])

# %%
pl_alphanum = Pipeline([
    ('union', process_and_join_features_alphanum),
    ('clf', OneVsRestClassifier(LogisticRegression()))
])

# %%
pl_basic = Pipeline([
    ('union', process_and_join_features_basic),
    ('clf', OneVsRestClassifier(LogisticRegression()))
])

# %%
X_train.head()
# Out:
#         FTE      Total Facility_or_Department     Function_Description  \
# 134338  1.0  50471.810                    NaN                      NaN
# 326408  1.0  62237.130                    NaN                      NaN
# 364634  NaN     22.300                    NaN  UNALLOC BUDGETS/SCHOOLS
# 47683   NaN     54.166                    NaN              NON-PROJECT
# 229958  NaN     -8.150                    NaN              NON-PROJECT
#
#               Fund_Description       Job_Title_Description  \
# 134338            General Fund         Teacher-Elementary
# 326408  General Purpose School             TCHER 2ND GRADE
# 364634                     NaN    Teacher, Short Term Sub
# 47683                      NaN  Teacher, Secondary (High)
# 229958                     NaN     Custodian - PT -  Jobs
#
#        Location_Description            Object_Description  \
# 134338                  NaN                           NaN
# 326408                  NaN  Personal Services - Teachers
# 364634                  NaN             EMPLOYEE BENEFITS
# 47683                   NaN  TEACHER COVERAGE FOR TEACHER
# 229958                  NaN               CONTRA BENEFITS
#
#                     Position_Extra             Program_Description  \
# 134338               KINDERGARTEN                     KINDERGARTEN
# 326408                     TEACHER           Instruction - Regular
# 364634  PROFESSIONAL-INSTRUCTIONAL  GENERAL MIDDLE/JUNIOR HIGH SCH
# 47683   PROFESSIONAL-INSTRUCTIONAL   GENERAL HIGH SCHOOL EDUCATION
# 229958                UNDESIGNATED               EMPLOYEE BENEFITS
#
#        SubFund_Description Sub_Object_Description               Text_1  \
# 134338                 NaN                    NaN                  NaN
# 326408                 NaN                    NaN                  NaN
# 364634        GENERAL FUND                    NaN  REGULAR INSTRUCTION
# 47683         GENERAL FUND                    NaN  REGULAR INSTRUCTION
# 229958        GENERAL FUND                    NaN    EMPLOYEE BENEFITS
#
#               Text_2       Text_3               Text_4
# 134338           NaN          NaN                  NaN
# 326408           NaN          NaN  Regular Instruction
# 364634  TEACHER SUBS      Regular                  NaN
# 47683   TEACHER SUBS  Alternative                  NaN
# 229958           NaN          n/a                  NaN

# %%
y_train.head()
# Out:
#         Function_Aides Compensation  Function_Career & Academic Counseling  \
# 134338                            0                                      0
# 326408                            0                                      0
# 364634                            0                                      0
# 47683                             0                                      0
# 229958                            0                                      0
#
#         Function_Communications  Function_Curriculum Development  \
# 134338                        0                                0
# 326408                        0                                0
# 364634                        0                                0
# 47683                         0                                0
# 229958                        0                                0
#
#         Function_Data Processing & Information Services  \
# 134338                                                0
# 326408                                                0
# 364634                                                0
# 47683                                                 0
# 229958                                                0
#
#         Function_Development & Fundraising  Function_Enrichment  \
# 134338                                   0                    0
# 326408                                   0                    0
# 364634                                   0                    0
# 47683                                    0                    0
# 229958                                   0                    0
#
#         Function_Extended Time & Tutoring  Function_Facilities & Maintenance  \
# 134338                                  0                                  0
# 326408                                  0                                  0
# 364634                                  0                                  0
# 47683                                   0                                  0
# 229958                                  0                                  1
#
#         Function_Facilities Planning                 ...                  \
# 134338                             0                 ...
# 326408                             0                 ...
# 364634                             0                 ...
# 47683                              0                 ...
# 229958                             0                 ...
#
#         Object_Type_Rent/Utilities  Object_Type_Substitute Compensation  \
# 134338                           0                                    0
# 326408                           0                                    0
# 364634                           0                                    0
# 47683                            0                                    1
# 229958                           0                                    0
#
#         Object_Type_Supplies/Materials  Object_Type_Travel & Conferences  \
# 134338                               0                                 0
# 326408                               0                                 0
# 364634                               0                                 0
# 47683                                0                                 0
# 229958                               0                                 0
#
#         Pre_K_NO_LABEL  Pre_K_Non PreK  Pre_K_PreK  \
# 134338               1               0           0
# 326408               0               1           0
# 364634               1               0           0
# 47683                1               0           0
# 229958               1               0           0
#
#         Operating_Status_Non-Operating  \
# 134338                               0
# 326408                               0
# 364634                               0
# 47683                                0
# 229958                               0
#
#         Operating_Status_Operating, Not PreK-12  \
# 134338                                        0
# 326408                                        0
# 364634                                        0
# 47683                                         0
# 229958                                        0
#
#         Operating_Status_PreK-12 Operating
# 134338                                   1
# 326408                                   1
# 364634                                   1
# 47683                                    1
# 229958                                   1
#
# [5 rows x 104 columns]

# %%
pl.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric_features', Pipeline(memory=None,
#      steps=[('selector', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprec...=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1))])

# %%
pl.score(X_test, y_test)
# Out:
# 0.3695459371681969

# %%
pl_alphanum.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric_features', Pipeline(memory=None,
#      steps=[('selector', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprec...=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1))])

# %%
pl_alphanum.score(X_test, y_test)
# Out:
# 0.35267003934794827

# %%
pl_basic.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric_features', Pipeline(memory=None,
#      steps=[('selector', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprec...=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1))])

# %%
pl_basic.score(X_test, y_test)
# Out:
# 0.3658609705827244

# %% [markdown]
# When no parameter is passed to CountVectorizer, it uses the default value: From sklearn documentation:  The default regexp select tokens of 2 or more alphanumeric characters (punctuation is completely ignored and always treated as a token separator)

# %% [markdown]
# Let's test another model. See how using pipeline makes it all very nifty.

# %%
plRF = Pipeline([
    ('union', process_and_join_features),
    ('clf', OneVsRestClassifier(RandomForestClassifier()))
])

# %%
plRF.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric_features', Pipeline(memory=None,
#      steps=[('selector', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprec... oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#           n_jobs=1))])

# %%
plRF.score(X_test, y_test)
# Out:
# 0.8991068640309787

# %% [markdown]
# Wow! Huge improvement on the score.

# %% [markdown]
# Evidently RandomForestClassifier() works with multiclass labels out of the box.

# %% [markdown]
# ** Using n-grams and MaxAbsScaler **

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
pl = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data),
                    ('imputer', Imputer())
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer', CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                   ngram_range=(1,2)))
                ]))
             ]
        )),
        ('scale', MaxAbsScaler()),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])

# %%
pl.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('union', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric_features', Pipeline(memory=None,
#      steps=[('selector', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x12fb00158>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y='deprec...=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1))])

# %%
pl.score(X_test, y_test)
# Out:
# 0.9202298419836362

# %% [markdown]
# SparseInteractions code from https://github.com/drivendataorg/box-plots-sklearn/blob/master/src/features/SparseInteractions.py
#
# SparseInteractions does the same thing as sklearn.preprocessing.PolynomialFeatures, but it uses sparse matrices to do so.

# %%
from itertools import combinations

import numpy as np
from scipy import sparse
from sklearn.base import BaseEstimator, TransformerMixin


class SparseInteractions(BaseEstimator, TransformerMixin):
    def __init__(self, degree=2, feature_name_separator="_"):
        self.degree = degree
        self.feature_name_separator = feature_name_separator

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        if not sparse.isspmatrix_csc(X):
            X = sparse.csc_matrix(X)

        if hasattr(X, "columns"):
            self.orig_col_names = X.columns
        else:
            self.orig_col_names = np.array([str(i) for i in range(X.shape[1])])

        spi = self._create_sparse_interactions(X)
        return spi

    def get_feature_names(self):
        return self.feature_names

    def _create_sparse_interactions(self, X):
        out_mat = []
        self.feature_names = self.orig_col_names.tolist()

        for sub_degree in range(2, self.degree + 1):
            for col_ixs in combinations(range(X.shape[1]), sub_degree):
                # add name for new column
                name = self.feature_name_separator.join(self.orig_col_names[list(col_ixs)])
                self.feature_names.append(name)

                # get column multiplications value
                out = X[:, col_ixs[0]]
                for j in col_ixs[1:]:
                    out = out.multiply(X[:, j])

                out_mat.append(out)

        return sparse.hstack([X] + out_mat)

# %% [markdown]
# Implementing the interaction model

# %%
pl = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data),
                    ('imputer', Imputer())
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer', CountVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                   ngram_range=(1, 2)))
                ]))
             ]
        )),
        ('int', SparseInteractions(degree=2)),
        ('scale', MaxAbsScaler()),
        ('clf', OneVsRestClassifier(LogisticRegression()))
    ])

# %% [markdown]
# Using HashingVectorizer to speed things up

# %%
# Import HashingVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

# Get text data: text_data
text_data = combine_text_columns(X_train)

# Create the token pattern: TOKENS_ALPHANUMERIC
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)' 

# Instantiate the HashingVectorizer: hashing_vec
hashing_vec = HashingVectorizer(token_pattern = TOKENS_ALPHANUMERIC)

# Fit and transform the Hashing Vectorizer
hashed_text = hashing_vec.fit_transform(text_data)

# Create DataFrame and print the head
hashed_df = pd.DataFrame(hashed_text.data)

# %%
hashed_text
# Out:
# <320222x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4658891 stored elements in Compressed Sparse Row format>

# %%
hashed_text.data
# Out:
# array([ 0.37796447,  0.75592895,  0.37796447, ..., -0.12598816,
#        -0.12598816, -0.12598816])

# %%
hashed_df.head()
# Out:
#           0
# 0  0.377964
# 1  0.755929
# 2  0.377964
# 3  0.377964
# 4  0.258199

# %%
text_data.head()
# Out:
# 134338      General Fund Teacher-Elementary    KINDERGAR...
# 326408      General Purpose School TCHER 2ND GRADE  Pers...
# 364634     UNALLOC BUDGETS/SCHOOLS  Teacher, Short Term ...
# 47683      NON-PROJECT  Teacher, Secondary (High)   TEAC...
# 229958     NON-PROJECT  Custodian - PT -  Jobs   CONTRA ...
# dtype: object
